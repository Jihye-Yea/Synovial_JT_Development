# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
import scipy as sp
import numpy as np
import warnings
import pySingleCellNet as pySCN

warnings.filterwarnings('ignore')
sc.settings.set_figure_params(dpi=80)
# Out:
# C:\Users\yeaji\anaconda3\Lib\site-packages\umap\distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# C:\Users\yeaji\anaconda3\Lib\site-packages\umap\distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# C:\Users\yeaji\anaconda3\Lib\site-packages\umap\distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# C:\Users\yeaji\anaconda3\Lib\site-packages\umap\umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %%
e125 = sc.read("C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/adJointDev_ALL_032322v2.h5ad")

# %%
e125.obs["timepoint"]
# Out:
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0    e12.5
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0    e12.5
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0    e12.5
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0    e12.5
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0    e12.5
#                                         ...
# qb_E17-5_gdf:TTGCGTCGTGTGGTTTx-1-1      e17.5
# qb_E17-5_gdf:TTTGTCACATCCCACTx-1-1      e17.5
# qb_E17-5_gdf:TTGGCAATCACAACGTx-1-1      e17.5
# qb_E17-5_gdf:TTTGGTTTCGACGGAAx-1-1      e17.5
# qb_E17-5_gdf:TTGGCAAAGTGGGCTAx-1-1      e17.5
# Name: timepoint, Length: 12096, dtype: category
# Categories (5, object): ['e12.5', 'e13.5', 'e14.5', 'e15.5', 'e17.5']

# %%
e125.obs["timepoint"]=="e12.5"
# Out:
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0     True
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0     True
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0     True
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0     True
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0     True
#                                         ...
# qb_E17-5_gdf:TTGCGTCGTGTGGTTTx-1-1      False
# qb_E17-5_gdf:TTTGTCACATCCCACTx-1-1      False
# qb_E17-5_gdf:TTGGCAATCACAACGTx-1-1      False
# qb_E17-5_gdf:TTTGGTTTCGACGGAAx-1-1      False
# qb_E17-5_gdf:TTGGCAAAGTGGGCTAx-1-1      False
# Name: timepoint, Length: 12096, dtype: bool

# %%
indicator = e125.obs["timepoint"]=="e12.5"
e125 = e125[indicator,:]

# %%
e125.obs
# Out:
#                                      timepoint         ann1       level1  \
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0     e12.5        joint          SC1
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0     e12.5      cycling          SC1
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0     e12.5        joint          SC1
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0     e12.5      cycling          SC1
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0     e12.5        joint          SC1
# ...                                        ...          ...          ...
# qb_E12-5_gdf:TTGCGTCAGTCTCCTCx-0-0-1     e12.5      myocyte      myocyte
# qb_E12-5_gdf:TTGCGTCCAAAGGTGCx-0-0-1     e12.5      myocyte      myocyte
# qb_E12-5_gdf:TTGGCAAAGTAGCGGTx-0-0-1     e12.5      myocyte      myocyte
# qb_E12-5_gdf:TTTCCTCGTAAACCTCx-0-0-1     e12.5  endothelial  endothelial
# qb_E12-5_gdf:TTTCCTCGTCTAGAGGx-0-0-1     e12.5      myocyte      myocyte
#
#                                            level2       level3 topLevel batch
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0        SC1_A       SC1_A1      GLE     0
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0        SC1_A       SC1_A4      GLE     0
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0        SC1_A       SC1_A1      GLE     0
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0        SC1_A       SC1_A4      GLE     0
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0        SC1_B       SC1_B4      GLE     0
# ...                                           ...          ...      ...   ...
# qb_E12-5_gdf:TTGCGTCAGTCTCCTCx-0-0-1      myocyte      myocyte  non-GLE     1
# qb_E12-5_gdf:TTGCGTCCAAAGGTGCx-0-0-1      myocyte      myocyte  non-GLE     1
# qb_E12-5_gdf:TTGGCAAAGTAGCGGTx-0-0-1      myocyte      myocyte  non-GLE     1
# qb_E12-5_gdf:TTTCCTCGTAAACCTCx-0-0-1  endothelial  endothelial  non-GLE     1
# qb_E12-5_gdf:TTTCCTCGTCTAGAGGx-0-0-1      myocyte      myocyte  non-GLE     1
#
# [2906 rows x 7 columns]

# %%
e125.write_h5ad("C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/e125_raw.h5ad")

# %%
e125
# Out:
# View of AnnData object with n_obs × n_vars = 2906 × 31065
#     obs: 'timepoint', 'ann1', 'level1', 'level2', 'level3', 'topLevel', 'batch'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'

# %%
e125.obs
# Out:
#                                      timepoint         ann1       level1  \
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0     e12.5        joint          SC1
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0     e12.5      cycling          SC1
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0     e12.5        joint          SC1
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0     e12.5      cycling          SC1
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0     e12.5        joint          SC1
# ...                                        ...          ...          ...
# qb_E12-5_gdf:TTGCGTCAGTCTCCTCx-0-0-1     e12.5      myocyte      myocyte
# qb_E12-5_gdf:TTGCGTCCAAAGGTGCx-0-0-1     e12.5      myocyte      myocyte
# qb_E12-5_gdf:TTGGCAAAGTAGCGGTx-0-0-1     e12.5      myocyte      myocyte
# qb_E12-5_gdf:TTTCCTCGTAAACCTCx-0-0-1     e12.5  endothelial  endothelial
# qb_E12-5_gdf:TTTCCTCGTCTAGAGGx-0-0-1     e12.5      myocyte      myocyte
#
#                                            level2       level3 topLevel batch
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0        SC1_A       SC1_A1      GLE     0
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0        SC1_A       SC1_A4      GLE     0
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0        SC1_A       SC1_A1      GLE     0
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0        SC1_A       SC1_A4      GLE     0
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0        SC1_B       SC1_B4      GLE     0
# ...                                           ...          ...      ...   ...
# qb_E12-5_gdf:TTGCGTCAGTCTCCTCx-0-0-1      myocyte      myocyte  non-GLE     1
# qb_E12-5_gdf:TTGCGTCCAAAGGTGCx-0-0-1      myocyte      myocyte  non-GLE     1
# qb_E12-5_gdf:TTGGCAAAGTAGCGGTx-0-0-1      myocyte      myocyte  non-GLE     1
# qb_E12-5_gdf:TTTCCTCGTAAACCTCx-0-0-1  endothelial  endothelial  non-GLE     1
# qb_E12-5_gdf:TTTCCTCGTCTAGAGGx-0-0-1      myocyte      myocyte  non-GLE     1
#
# [2906 rows x 7 columns]

# %%
e125.obs_names
# Out:
# Index(['qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0',
#        'qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0',
#        'qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0',
#        'qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0',
#        'qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0',
#        'qb_E12-5_gdf:AAACCTGTCGATCCCTx-0-0-0',
#        'qb_E12-5_gdf:AAACCTGTCGTAGATCx-0-0-0',
#        'qb_E12-5_gdf:AAACGGGAGAATGTTGx-0-0-0',
#        'qb_E12-5_gdf:AAACGGGCAAGTCTGTx-0-0-0',
#        'qb_E12-5_gdf:AAACGGGCACAAGACGx-0-0-0',
#        ...
#        'qb_E12-5_gdf:TTATGCTAGATCGGGTx-0-0-1',
#        'qb_E12-5_gdf:TTCGAAGCATGGGACAx-0-0-1',
#        'qb_E12-5_gdf:TTCGGTCCATAGACTCx-0-0-1',
#        'qb_E12-5_gdf:TTCTACAGTTACAGAAx-0-0-1',
#        'qb_E12-5_gdf:TTCTCAACAGGACCCTx-0-0-1',
#        'qb_E12-5_gdf:TTGCGTCAGTCTCCTCx-0-0-1',
#        'qb_E12-5_gdf:TTGCGTCCAAAGGTGCx-0-0-1',
#        'qb_E12-5_gdf:TTGGCAAAGTAGCGGTx-0-0-1',
#        'qb_E12-5_gdf:TTTCCTCGTAAACCTCx-0-0-1',
#        'qb_E12-5_gdf:TTTCCTCGTCTAGAGGx-0-0-1'],
#       dtype='object', length=2906)

# %%
e125.var
# Out:
#                                    Accession             Chromosome      End  \
# Xkr4                      ENSMUSG00000051951                      1  3671498
# Gm37381                   ENSMUSG00000102343                      1  3986215
# Rp1                       ENSMUSG00000025900                      1  4409241
# Sox17                     ENSMUSG00000025902                      1  4497354
# Gm37323                   ENSMUSG00000104328                      1  4586252
# ...                                      ...                    ...      ...
# selection_hygromycinB  selection_hygromycinB  selection_hygromycinB     1025
# selection_kanamycin      selection_kanamycin    selection_kanamycin      794
# selection_neomycin        selection_neomycin     selection_neomycin      815
# selection_puromycin      selection_puromycin    selection_puromycin      599
# selection_zeocin            selection_zeocin       selection_zeocin      374
#
#                          Start Strand
# Xkr4                   3205901      -
# Gm37381                3905739      -
# Rp1                    3999557      -
# Sox17                  4490931      -
# Gm37323                4583129      -
# ...                        ...    ...
# selection_hygromycinB        1      +
# selection_kanamycin          1      +
# selection_neomycin           1      +
# selection_puromycin          1      +
# selection_zeocin             1      +
#
# [31065 rows x 5 columns]

# %% [markdown]
# # QC

# %%
#checks if the gene name (var) starts with 'mt' or 'ribo' via string methods
e125.var['mt']= e125.var_names.str.startswith(("mt-"))
print(sum(e125.var['mt']))
# Out:
# 13

# %%
e125.var['ribo'] = e125.var_names.str.startswith(("Rps","Rpl"))
print(sum(e125.var['ribo']))
# Out:
# 105

# %%
e125.var
# Out:
#                                    Accession             Chromosome      End  \
# Xkr4                      ENSMUSG00000051951                      1  3671498
# Gm37381                   ENSMUSG00000102343                      1  3986215
# Rp1                       ENSMUSG00000025900                      1  4409241
# Sox17                     ENSMUSG00000025902                      1  4497354
# Gm37323                   ENSMUSG00000104328                      1  4586252
# ...                                      ...                    ...      ...
# selection_hygromycinB  selection_hygromycinB  selection_hygromycinB     1025
# selection_kanamycin      selection_kanamycin    selection_kanamycin      794
# selection_neomycin        selection_neomycin     selection_neomycin      815
# selection_puromycin      selection_puromycin    selection_puromycin      599
# selection_zeocin            selection_zeocin       selection_zeocin      374
#
#                          Start Strand     mt   ribo
# Xkr4                   3205901      -  False  False
# Gm37381                3905739      -  False  False
# Rp1                    3999557      -  False  False
# Sox17                  4490931      -  False  False
# Gm37323                4583129      -  False  False
# ...                        ...    ...    ...    ...
# selection_hygromycinB        1      +  False  False
# selection_kanamycin          1      +  False  False
# selection_neomycin           1      +  False  False
# selection_puromycin          1      +  False  False
# selection_zeocin             1      +  False  False
#
# [31065 rows x 7 columns]

# %%
sc.pp.calculate_qc_metrics(e125, qc_vars=['ribo', 'mt'], percent_top=None, log1p=False, inplace=True)

# %%
axs = sc.pl.violin(e125, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'pct_counts_ribo'],jitter=0.4, multi_panel=True)

# %%
sc.pl.scatter(e125, x='total_counts', y='n_genes_by_counts')

# %%
e125= e125[e125.obs['total_counts'] < 18000, :]
e125 = e125[e125.obs['pct_counts_mt'] < 2.5, :]
# filter for percent ribo > 0.05
e125 = e125[e125.obs['pct_counts_ribo'] < 60, :]
axs = sc.pl.violin(e125, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'pct_counts_ribo'],jitter=0.4, multi_panel=True)

# %%
sc.pl.scatter(e125, x='total_counts', y='n_genes_by_counts')

# %%
sc.pp.calculate_qc_metrics(e125, qc_vars=['ribo', 'mt'], percent_top=None, log1p=False, inplace=True)

# %%
e125 = e125[e125.obs['n_genes_by_counts'] > 500, :]

# %% [markdown]
# # Remove genes we don't care about (ribo, malat, mito) and are expressed in less than 5 cells

# %%
sc.pp.filter_genes(e125, min_cells=5)


print("Number of cells: ",e125.n_obs)

#save a copy of anndata before normalization 
e125 = e125.copy()

##remove MT, ribo, and maltat reads since these reads are highly abundant, but not relevant to expirement
mito_genes = e125.var_names.str.startswith("mt-")
ribo_genes = e125.var_names.str.startswith(("Rps","Rpl"))
malat_gene = e125.var_names.str.startswith("Malat1")

remove = np.add(mito_genes, ribo_genes)
remove = np.add(remove, malat_gene)
keep = np.invert(remove)

print(len(remove))

print(np.count_nonzero(keep))
print(len(keep) - np.count_nonzero(keep))

e125 = e125[:,keep].copy()

print("Number of genes: ",e125.n_vars)
# Out:
# Number of cells:  2906
# 14512
# 14404
# 108
# Number of genes:  14404

# %% [markdown]
# # SCN using Qin's data to train
#
# Load in Qin's data

# %%
adTrain = sc.read_h5ad("C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/adJointDev_ALL_032322v2.h5ad")

# %%
adTrain.var_names_make_unique()

# %%
qDat = e125.copy()
qDat.var_names_make_unique()

# %%
genesTrain = adTrain.var_names
genesQuery = qDat.var_names
cgenes = genesTrain.intersection(genesQuery)
print(len(cgenes))

adTrain1 = adTrain[:,cgenes]
adQuery = qDat[:,cgenes].copy()
adTrain1 = adTrain1[~adTrain1.obs.index.duplicated()]
# Out:
# 14404

# %%
qDat.obs
# Out:
#                                      timepoint         ann1       level1  \
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0     e12.5        joint          SC1
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0     e12.5      cycling          SC1
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0     e12.5        joint          SC1
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0     e12.5      cycling          SC1
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0     e12.5        joint          SC1
# ...                                        ...          ...          ...
# qb_E12-5_gdf:TTGCGTCAGTCTCCTCx-0-0-1     e12.5      myocyte      myocyte
# qb_E12-5_gdf:TTGCGTCCAAAGGTGCx-0-0-1     e12.5      myocyte      myocyte
# qb_E12-5_gdf:TTGGCAAAGTAGCGGTx-0-0-1     e12.5      myocyte      myocyte
# qb_E12-5_gdf:TTTCCTCGTAAACCTCx-0-0-1     e12.5  endothelial  endothelial
# qb_E12-5_gdf:TTTCCTCGTCTAGAGGx-0-0-1     e12.5      myocyte      myocyte
#
#                                            level2       level3 topLevel batch  \
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0        SC1_A       SC1_A1      GLE     0
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0        SC1_A       SC1_A4      GLE     0
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0        SC1_A       SC1_A1      GLE     0
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0        SC1_A       SC1_A4      GLE     0
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0        SC1_B       SC1_B4      GLE     0
# ...                                           ...          ...      ...   ...
# qb_E12-5_gdf:TTGCGTCAGTCTCCTCx-0-0-1      myocyte      myocyte  non-GLE     1
# qb_E12-5_gdf:TTGCGTCCAAAGGTGCx-0-0-1      myocyte      myocyte  non-GLE     1
# qb_E12-5_gdf:TTGGCAAAGTAGCGGTx-0-0-1      myocyte      myocyte  non-GLE     1
# qb_E12-5_gdf:TTTCCTCGTAAACCTCx-0-0-1  endothelial  endothelial  non-GLE     1
# qb_E12-5_gdf:TTTCCTCGTCTAGAGGx-0-0-1      myocyte      myocyte  non-GLE     1
#
#                                       n_genes_by_counts  total_counts  \
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0               2130        5934.0
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0               2609        7305.0
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0               1094        2010.0
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0               2702        7125.0
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0               1406        2604.0
# ...                                                 ...           ...
# qb_E12-5_gdf:TTGCGTCAGTCTCCTCx-0-0-1               3071       11692.0
# qb_E12-5_gdf:TTGCGTCCAAAGGTGCx-0-0-1               3409       11750.0
# qb_E12-5_gdf:TTGGCAAAGTAGCGGTx-0-0-1               2797       10921.0
# qb_E12-5_gdf:TTTCCTCGTAAACCTCx-0-0-1               2848        9626.0
# qb_E12-5_gdf:TTTCCTCGTCTAGAGGx-0-0-1               2608       10853.0
#
#                                       total_counts_ribo  pct_counts_ribo  \
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0             2072.0        34.917427
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0             1802.0        24.668036
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0              543.0        27.014927
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0             1612.0        22.624561
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0              501.0        19.239632
# ...                                                 ...              ...
# qb_E12-5_gdf:TTGCGTCAGTCTCCTCx-0-0-1             4566.0        39.052345
# qb_E12-5_gdf:TTGCGTCCAAAGGTGCx-0-0-1             3830.0        32.595745
# qb_E12-5_gdf:TTGGCAAAGTAGCGGTx-0-0-1             3759.0        34.419926
# qb_E12-5_gdf:TTTCCTCGTAAACCTCx-0-0-1             2450.0        25.451902
# qb_E12-5_gdf:TTTCCTCGTCTAGAGGx-0-0-1             4714.0        43.434994
#
#                                       total_counts_mt  pct_counts_mt
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0             54.0       0.910010
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0             66.0       0.903491
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0             15.0       0.746269
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0             72.0       1.010526
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0             50.0       1.920123
# ...                                               ...            ...
# qb_E12-5_gdf:TTGCGTCAGTCTCCTCx-0-0-1            142.0       1.214506
# qb_E12-5_gdf:TTGCGTCCAAAGGTGCx-0-0-1             92.0       0.782979
# qb_E12-5_gdf:TTGGCAAAGTAGCGGTx-0-0-1            140.0       1.281934
# qb_E12-5_gdf:TTTCCTCGTAAACCTCx-0-0-1             63.0       0.654477
# qb_E12-5_gdf:TTTCCTCGTCTAGAGGx-0-0-1            117.0       1.078043
#
# [2906 rows x 13 columns]

# %%
qDat.var
# Out:
#                         Accession Chromosome       End     Start Strand  \
# Sox17          ENSMUSG00000025902          1   4497354   4490931      -
# Mrpl15         ENSMUSG00000033845          1   4785739   4773206      -
# 4732440D04Rik  ENSMUSG00000090031          1   6215293   6209866      -
# Gm26901        ENSMUSG00000097797          1   7397869   7349406      -
# Mybl1          ENSMUSG00000025912          1   9700209   9667415      -
# ...                           ...        ...       ...       ...    ...
# Ddx3y          ENSMUSG00000069045          Y   1286629   1260771      -
# Kdm5d          ENSMUSG00000056673          Y    956786    897788      +
# Eif2s3y        ENSMUSG00000069049          Y   1028847   1010543      +
# Gm29650        ENSMUSG00000099876          Y   1049134   1048393      +
# Gm47283        ENSMUSG00000096768          Y  90816464  90784738      +
#
#                   mt   ribo  n_cells_by_counts  mean_counts  \
# Sox17          False  False                  9     0.010323
# Mrpl15         False  False                418     0.157261
# 4732440D04Rik  False  False                 18     0.006194
# Gm26901        False  False                  6     0.002065
# Mybl1          False  False                 27     0.009635
# ...              ...    ...                ...          ...
# Ddx3y          False  False               1314     0.667240
# Kdm5d          False  False                 67     0.023744
# Eif2s3y        False  False                913     0.384033
# Gm29650        False  False                 30     0.010668
# Gm47283        False  False               1448     0.898142
#
#                pct_dropout_by_counts  total_counts  n_cells
# Sox17                      99.690296          30.0        9
# Mrpl15                     85.615967         457.0      418
# 4732440D04Rik              99.380592          18.0       18
# Gm26901                    99.793531           6.0        6
# Mybl1                      99.070888          28.0       27
# ...                              ...           ...      ...
# Ddx3y                      54.783207        1939.0     1314
# Kdm5d                      97.694425          69.0       67
# Eif2s3y                    68.582244        1116.0      913
# Gm29650                    98.967653          31.0       30
# Gm47283                    50.172058        2610.0     1448
#
# [14404 rows x 12 columns]

# %% [markdown]
# # Split training data into two to check classifer later

# %%
expTrain, expVal = pySCN.splitCommonAnnData(adTrain1, ncells=200,dLevel="level2")
# Out:
# myocyte :
# 1128
# 2 :
# 354
# endothelial :
# 23
# 8 :
# 25
# SC3_B :
# 1070
# blood :
# 286
# SC1_A :
# 1791
# SC3_A :
# 2451
# 8 (prog) :
# 123
# 0 :
# 22
# 4 (synfib) :
# 26
# melanocyte :
# 15
# erythro :
# 6
# 1 (chon) :
# 90
# 9 (divi) :
# 141
# dermis :
# 964
# SC1_B :
# 895
# 3 (line) :
# 49
# 7 (prog) :
# 51
# 4 :
# 209
# ncc :
# 78
# SC2_B :
# 495
# 5 (stro) :
# 633
# 6 (stro) :
# 134
# 2 (liga) :
# 54
# 5 :
# 5
# 3 :
# 251
# 6 :
# 52
# 7 :
# 48
# SC2_A :
# 627

# %% [markdown]
# # Train the classifer

# %%
[cgenesA, xpairs, tspRF] = pySCN.scn_train(expTrain, nTopGenes = 100, nRand = 100, nTrees = 1000, nTopGenePairs = 100, dLevel = "level2", stratify=True, limitToHVG=True)
# Out:
# HVG
# Matrix normalized
# There are  1617  classification genes
#
# 0
# 1 (chon)
# 2
# 2 (liga)
# 3
# 3 (line)
# 4
# 4 (synfib)
# 5
# 5 (stro)
# 6
# 6 (stro)
# 7
# 7 (prog)
# 8
# 8 (prog)
# 9 (divi)
# SC1_A
# SC1_B
# SC2_A
# SC2_B
# SC3_A
# SC3_B
# blood
# dermis
# endothelial
# erythro
# melanocyte
# myocyte
# ncc
# There are 2854 top gene pairs
#
# Finished pair transforming the data

# %%
adVal = pySCN.scn_classify(expVal, cgenesA, xpairs, tspRF, nrand = 0)

ax = sc.pl.heatmap(adVal, adVal.var_names.values, groupby='SCN_class', cmap='viridis', dendrogram=False, swap_axes=True)

# %%
adQd5 = pySCN.scn_classify(adQuery, cgenesA, xpairs, tspRF, nrand = 0)

# %%
adQuery.obs = pd.concat([adQuery.obs, adQd5.obs['SCN_class']], axis=1)

# %% [markdown]
# # count normalization

# %%
e125 = adQuery.copy()

# %%
e125.write_h5ad("C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/e125_SCN.h5ad")

# %%
adata = sc.read_h5ad("C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/e125_SCN.h5ad")

# %%
adata.raw = adata
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=4, min_disp=0.25)

# %% [markdown]
# # Gene scaling

# %%
sc.pp.scale(adata, max_value=10)

# %% [markdown]
# # PCA (Principle components analysis)

# %%
sc.tl.pca(adata, svd_solver='arpack', use_highly_variable=True)
sc.pl.pca_variance_ratio(adata)

# %% [markdown]
# # *Fine neighbors

# %%
sc.pp.neighbors(adata)
sc.tl.leiden(adata, resolution =.3)
sc.tl.umap(adata, .25)

# %%
sc.pl.umap(adata, color=['leiden', 'SCN_class'], palette=sc.pl.palettes.default_20, )

# %%
adata.var
# Out:
#                         Accession Chromosome       End     Start Strand  \
# Sox17          ENSMUSG00000025902          1   4497354   4490931      -
# Mrpl15         ENSMUSG00000033845          1   4785739   4773206      -
# 4732440D04Rik  ENSMUSG00000090031          1   6215293   6209866      -
# Gm26901        ENSMUSG00000097797          1   7397869   7349406      -
# Mybl1          ENSMUSG00000025912          1   9700209   9667415      -
# ...                           ...        ...       ...       ...    ...
# Ddx3y          ENSMUSG00000069045          Y   1286629   1260771      -
# Kdm5d          ENSMUSG00000056673          Y    956786    897788      +
# Eif2s3y        ENSMUSG00000069049          Y   1028847   1010543      +
# Gm29650        ENSMUSG00000099876          Y   1049134   1048393      +
# Gm47283        ENSMUSG00000096768          Y  90816464  90784738      +
#
#                   mt   ribo  n_cells_by_counts  mean_counts  \
# Sox17          False  False                  9     0.010323
# Mrpl15         False  False                418     0.157261
# 4732440D04Rik  False  False                 18     0.006194
# Gm26901        False  False                  6     0.002065
# Mybl1          False  False                 27     0.009635
# ...              ...    ...                ...          ...
# Ddx3y          False  False               1314     0.667240
# Kdm5d          False  False                 67     0.023744
# Eif2s3y        False  False                913     0.384033
# Gm29650        False  False                 30     0.010668
# Gm47283        False  False               1448     0.898142
#
#                pct_dropout_by_counts  total_counts  n_cells  highly_variable  \
# Sox17                      99.690296          30.0        9             True
# Mrpl15                     85.615967         457.0      418            False
# 4732440D04Rik              99.380592          18.0       18             True
# Gm26901                    99.793531           6.0        6            False
# Mybl1                      99.070888          28.0       27             True
# ...                              ...           ...      ...              ...
# Ddx3y                      54.783207        1939.0     1314            False
# Kdm5d                      97.694425          69.0       67             True
# Eif2s3y                    68.582244        1116.0      913            False
# Gm29650                    98.967653          31.0       30            False
# Gm47283                    50.172058        2610.0     1448             True
#
#                   means  dispersions  dispersions_norm      mean       std
# Sox17          0.021020     2.237250          4.403293  0.005942  0.110689
# Mrpl15         0.303822     0.998402         -0.557698  0.171849  0.434364
# 4732440D04Rik  0.017911     1.348733          0.971659  0.008036  0.105382
# Gm26901        0.004190     0.812149         -1.100736  0.002245  0.050254
# Mybl1          0.027608     1.327971          0.891470  0.012337  0.131503
# ...                 ...          ...               ...       ...       ...
# Ddx3y          0.946449     1.188770         -0.108795  0.638325  0.752947
# Kdm5d          0.059702     1.207304          0.425432  0.028796  0.192822
# Eif2s3y        0.644816     1.022105         -0.451970  0.406513  0.630332
# Gm29650        0.022660     0.902241         -0.752786  0.011796  0.117823
# Gm47283        1.130503     1.481852          0.496783  0.759961  0.832324
#
# [14404 rows x 18 columns]

# %%
adata.obs
# Out:
#                                      timepoint         ann1       level1  \
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0     e12.5        joint          SC1
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0     e12.5      cycling          SC1
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0     e12.5        joint          SC1
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0     e12.5      cycling          SC1
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0     e12.5        joint          SC1
# ...                                        ...          ...          ...
# qb_E12-5_gdf:TTGCGTCAGTCTCCTCx-0-0-1     e12.5      myocyte      myocyte
# qb_E12-5_gdf:TTGCGTCCAAAGGTGCx-0-0-1     e12.5      myocyte      myocyte
# qb_E12-5_gdf:TTGGCAAAGTAGCGGTx-0-0-1     e12.5      myocyte      myocyte
# qb_E12-5_gdf:TTTCCTCGTAAACCTCx-0-0-1     e12.5  endothelial  endothelial
# qb_E12-5_gdf:TTTCCTCGTCTAGAGGx-0-0-1     e12.5      myocyte      myocyte
#
#                                            level2       level3 topLevel batch  \
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0        SC1_A       SC1_A1      GLE     0
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0        SC1_A       SC1_A4      GLE     0
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0        SC1_A       SC1_A1      GLE     0
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0        SC1_A       SC1_A4      GLE     0
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0        SC1_B       SC1_B4      GLE     0
# ...                                           ...          ...      ...   ...
# qb_E12-5_gdf:TTGCGTCAGTCTCCTCx-0-0-1      myocyte      myocyte  non-GLE     1
# qb_E12-5_gdf:TTGCGTCCAAAGGTGCx-0-0-1      myocyte      myocyte  non-GLE     1
# qb_E12-5_gdf:TTGGCAAAGTAGCGGTx-0-0-1      myocyte      myocyte  non-GLE     1
# qb_E12-5_gdf:TTTCCTCGTAAACCTCx-0-0-1  endothelial  endothelial  non-GLE     1
# qb_E12-5_gdf:TTTCCTCGTCTAGAGGx-0-0-1      myocyte      myocyte  non-GLE     1
#
#                                       n_genes_by_counts  total_counts  \
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0               2130        5934.0
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0               2609        7305.0
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0               1094        2010.0
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0               2702        7125.0
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0               1406        2604.0
# ...                                                 ...           ...
# qb_E12-5_gdf:TTGCGTCAGTCTCCTCx-0-0-1               3071       11692.0
# qb_E12-5_gdf:TTGCGTCCAAAGGTGCx-0-0-1               3409       11750.0
# qb_E12-5_gdf:TTGGCAAAGTAGCGGTx-0-0-1               2797       10921.0
# qb_E12-5_gdf:TTTCCTCGTAAACCTCx-0-0-1               2848        9626.0
# qb_E12-5_gdf:TTTCCTCGTCTAGAGGx-0-0-1               2608       10853.0
#
#                                       total_counts_ribo  pct_counts_ribo  \
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0             2072.0        34.917427
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0             1802.0        24.668036
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0              543.0        27.014927
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0             1612.0        22.624561
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0              501.0        19.239632
# ...                                                 ...              ...
# qb_E12-5_gdf:TTGCGTCAGTCTCCTCx-0-0-1             4566.0        39.052345
# qb_E12-5_gdf:TTGCGTCCAAAGGTGCx-0-0-1             3830.0        32.595745
# qb_E12-5_gdf:TTGGCAAAGTAGCGGTx-0-0-1             3759.0        34.419926
# qb_E12-5_gdf:TTTCCTCGTAAACCTCx-0-0-1             2450.0        25.451902
# qb_E12-5_gdf:TTTCCTCGTCTAGAGGx-0-0-1             4714.0        43.434994
#
#                                       total_counts_mt  pct_counts_mt  \
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0             54.0       0.910010
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0             66.0       0.903491
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0             15.0       0.746269
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0             72.0       1.010526
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0             50.0       1.920123
# ...                                               ...            ...
# qb_E12-5_gdf:TTGCGTCAGTCTCCTCx-0-0-1            142.0       1.214506
# qb_E12-5_gdf:TTGCGTCCAAAGGTGCx-0-0-1             92.0       0.782979
# qb_E12-5_gdf:TTGGCAAAGTAGCGGTx-0-0-1            140.0       1.281934
# qb_E12-5_gdf:TTTCCTCGTAAACCTCx-0-0-1             63.0       0.654477
# qb_E12-5_gdf:TTTCCTCGTCTAGAGGx-0-0-1            117.0       1.078043
#
#                                         SCN_class leiden
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0        SC1_A      0
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0        SC1_A      2
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0        SC1_A      0
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0        SC1_A      2
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0        SC1_B      1
# ...                                           ...    ...
# qb_E12-5_gdf:TTGCGTCAGTCTCCTCx-0-0-1      myocyte      3
# qb_E12-5_gdf:TTGCGTCCAAAGGTGCx-0-0-1      myocyte      3
# qb_E12-5_gdf:TTGGCAAAGTAGCGGTx-0-0-1      myocyte      3
# qb_E12-5_gdf:TTTCCTCGTAAACCTCx-0-0-1  endothelial      4
# qb_E12-5_gdf:TTTCCTCGTCTAGAGGx-0-0-1      myocyte      3
#
# [2906 rows x 15 columns]

# %%
adata = adata[~(adata.obs["SCN_class"] == "erythro")]

# %%
adata.obs['SCN_class'] == "SC1_A"
indicator = adata.obs["SCN_class"] == "SC1_A"
adata_SC1_A = adata [indicator,:]


adata_SC1_A.var['total_expression'] = adata_SC1_A.X.sum(0)
adata_SC1_A.var['total_expression'].nlargest(100) 
top_expression_genes_adata_SC1_A = adata_SC1_A.var['total_expression'].nlargest(100)
top_expression_genes_adata_SC1_A_df = pd.DataFrame(top_expression_genes_adata_SC1_A)
top_expression_genes_adata_SC1_A_df.to_excel('C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/excel/SCN_cluster/e125_highly_expr_genes_SC1_A.xlsx', index=True)

# %%
adata.obs['SCN_class'] == "SC1_B"
indicator = adata.obs["SCN_class"] == "SC1_B"
adata_SC1_B = adata [indicator,:]

adata_SC1_B.var['total_expression'] = adata_SC1_B.X.sum(0)
adata_SC1_B.var['total_expression'].nlargest(100) 
top_expression_genes_adata_SC1_B = adata_SC1_B.var['total_expression'].nlargest(100)
top_expression_genes_adata_SC1_B_df = pd.DataFrame(top_expression_genes_adata_SC1_B)
top_expression_genes_adata_SC1_B_df.to_excel('C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/excel/SCN_cluster/e125_highly_expr_genes_SC1_B.xlsx', index=True)

# %%
adata.obs['SCN_class'] == "SC2_A"
indicator = adata.obs["SCN_class"] == "SC2_A"
adata_SC2_A = adata [indicator,:]

adata_SC2_A.var['total_expression'] = adata_SC2_A.X.sum(0)
adata_SC2_A.var['total_expression'].nlargest(100) 
top_expression_genes_adata_SC2_A = adata_SC2_A.var['total_expression'].nlargest(100)
top_expression_genes_adata_SC2_A_df = pd.DataFrame(top_expression_genes_adata_SC2_A)
top_expression_genes_adata_SC2_A_df.to_excel('C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/excel/SCN_cluster/e125_highly_expr_genes_SC2_A.xlsx', index=True)

# %%
adata.obs['SCN_class'] == "SC3_A"
indicator = adata.obs["SCN_class"] == "SC3_A"
adata_SC3_A = adata [indicator,:]

adata_SC3_A.var['total_expression'] = adata_SC3_A.X.sum(0)
adata_SC3_A.var['total_expression'].nlargest(100) 
top_expression_genes_adata_SC3_A = adata_SC3_A.var['total_expression'].nlargest(100)
top_expression_genes_adata_SC3_A_df = pd.DataFrame(top_expression_genes_adata_SC3_A)
top_expression_genes_adata_SC3_A_df.to_excel('C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/excel/SCN_cluster/e125_highly_expr_genes_SC3_A.xlsx', index=True)
