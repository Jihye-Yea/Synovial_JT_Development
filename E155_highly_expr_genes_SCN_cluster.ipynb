# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
import scipy as sp
import numpy as np
import warnings
import pySingleCellNet as pySCN

warnings.filterwarnings('ignore')
sc.settings.set_figure_params(dpi=80)
# Out:
# C:\Users\yeaji\anaconda3\Lib\site-packages\umap\distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# C:\Users\yeaji\anaconda3\Lib\site-packages\umap\distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# C:\Users\yeaji\anaconda3\Lib\site-packages\umap\distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# C:\Users\yeaji\anaconda3\Lib\site-packages\umap\umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %%
e155 = sc.read("C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/adJointDev_ALL_032322v2.h5ad")

# %%
e155.obs['timepoint']=="E15.5"
# Out:
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0    False
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0    False
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0    False
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0    False
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0    False
#                                         ...
# qb_E17-5_gdf:TTGCGTCGTGTGGTTTx-1-1      False
# qb_E17-5_gdf:TTTGTCACATCCCACTx-1-1      False
# qb_E17-5_gdf:TTGGCAATCACAACGTx-1-1      False
# qb_E17-5_gdf:TTTGGTTTCGACGGAAx-1-1      False
# qb_E17-5_gdf:TTGGCAAAGTGGGCTAx-1-1      False
# Name: timepoint, Length: 12096, dtype: bool

# %%
indicator = e155.obs["timepoint"]=="e15.5"
e155 = e155[indicator,:]

# %%
e155.write_h5ad("C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/e155_raw.h5ad")

# %%
e155
# Out:
# View of AnnData object with n_obs × n_vars = 1003 × 31065
#     obs: 'timepoint', 'ann1', 'level1', 'level2', 'level3', 'topLevel', 'batch'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'

# %%
e155.obs
# Out:
#                                      timepoint     ann1   level1   level2  \
# qb_E15-5_gdf:AAACCTGTCAACACTGx-3-0-0     e15.5    joint      SC3    SC3_B
# qb_E15-5_gdf:AAACGGGCATGTAGTCx-3-0-0     e15.5    joint      SC3    SC3_B
# qb_E15-5_gdf:AAACGGGCATTCCTCGx-3-0-0     e15.5    joint      SC3    SC3_B
# qb_E15-5_gdf:AAACGGGTCCAAGCCGx-3-0-0     e15.5    joint      SC3    SC3_B
# qb_E15-5_gdf:AAAGATGCAATGTAAGx-3-0-0     e15.5    joint      SC2    SC2_B
# ...                                        ...      ...      ...      ...
# qb_E15-5_gdf:TTATGCTTCACTCTTAx-3-0-1     e15.5   dermis   dermis   dermis
# qb_E15-5_gdf:TTCCCAGTCTCCGGTTx-3-0-1     e15.5   dermis   dermis   dermis
# qb_E15-5_gdf:TTCGAAGAGCAGATCGx-3-0-1     e15.5  myocyte  myocyte  myocyte
# qb_E15-5_gdf:TTGTAGGTCACCGGGTx-3-0-1     e15.5   dermis   dermis   dermis
# qb_E15-5_gdf:TTTGGTTAGATAGTCAx-3-0-1     e15.5    blood    blood    blood
#
#                                        level3 topLevel batch
# qb_E15-5_gdf:AAACCTGTCAACACTGx-3-0-0   SC3_B1      GLE     0
# qb_E15-5_gdf:AAACGGGCATGTAGTCx-3-0-0   SC3_B1      GLE     0
# qb_E15-5_gdf:AAACGGGCATTCCTCGx-3-0-0   SC3_B1      GLE     0
# qb_E15-5_gdf:AAACGGGTCCAAGCCGx-3-0-0   SC3_B1      GLE     0
# qb_E15-5_gdf:AAAGATGCAATGTAAGx-3-0-0   SC2_B1      GLE     0
# ...                                       ...      ...   ...
# qb_E15-5_gdf:TTATGCTTCACTCTTAx-3-0-1   dermis  non-GLE     1
# qb_E15-5_gdf:TTCCCAGTCTCCGGTTx-3-0-1   dermis  non-GLE     1
# qb_E15-5_gdf:TTCGAAGAGCAGATCGx-3-0-1  myocyte  non-GLE     1
# qb_E15-5_gdf:TTGTAGGTCACCGGGTx-3-0-1   dermis  non-GLE     1
# qb_E15-5_gdf:TTTGGTTAGATAGTCAx-3-0-1    blood  non-GLE     1
#
# [1003 rows x 7 columns]

# %%
e155.obs_names
# Out:
# Index(['qb_E15-5_gdf:AAACCTGTCAACACTGx-3-0-0',
#        'qb_E15-5_gdf:AAACGGGCATGTAGTCx-3-0-0',
#        'qb_E15-5_gdf:AAACGGGCATTCCTCGx-3-0-0',
#        'qb_E15-5_gdf:AAACGGGTCCAAGCCGx-3-0-0',
#        'qb_E15-5_gdf:AAAGATGCAATGTAAGx-3-0-0',
#        'qb_E15-5_gdf:AAAGATGGTTGTACACx-3-0-0',
#        'qb_E15-5_gdf:AAAGATGTCTGGCGACx-3-0-0',
#        'qb_E15-5_gdf:AAAGTAGAGAATTCCCx-3-0-0',
#        'qb_E15-5_gdf:AAAGTAGAGGTGATATx-3-0-0',
#        'qb_E15-5_gdf:AAAGTAGGTAGATTAGx-3-0-0',
#        ...
#        'qb_E15-5_gdf:TGAGGGATCGGTTCGGx-3-0-1',
#        'qb_E15-5_gdf:TGCCAAAAGGAGTTTAx-3-0-1',
#        'qb_E15-5_gdf:TGTATTCTCTTTAGTCx-3-0-1',
#        'qb_E15-5_gdf:TTAGGACAGGGTCTCCx-3-0-1',
#        'qb_E15-5_gdf:TTAGGACTCCTTTCGGx-3-0-1',
#        'qb_E15-5_gdf:TTATGCTTCACTCTTAx-3-0-1',
#        'qb_E15-5_gdf:TTCCCAGTCTCCGGTTx-3-0-1',
#        'qb_E15-5_gdf:TTCGAAGAGCAGATCGx-3-0-1',
#        'qb_E15-5_gdf:TTGTAGGTCACCGGGTx-3-0-1',
#        'qb_E15-5_gdf:TTTGGTTAGATAGTCAx-3-0-1'],
#       dtype='object', length=1003)

# %%
e155.var
# Out:
#                                    Accession             Chromosome      End  \
# Xkr4                      ENSMUSG00000051951                      1  3671498
# Gm37381                   ENSMUSG00000102343                      1  3986215
# Rp1                       ENSMUSG00000025900                      1  4409241
# Sox17                     ENSMUSG00000025902                      1  4497354
# Gm37323                   ENSMUSG00000104328                      1  4586252
# ...                                      ...                    ...      ...
# selection_hygromycinB  selection_hygromycinB  selection_hygromycinB     1025
# selection_kanamycin      selection_kanamycin    selection_kanamycin      794
# selection_neomycin        selection_neomycin     selection_neomycin      815
# selection_puromycin      selection_puromycin    selection_puromycin      599
# selection_zeocin            selection_zeocin       selection_zeocin      374
#
#                          Start Strand
# Xkr4                   3205901      -
# Gm37381                3905739      -
# Rp1                    3999557      -
# Sox17                  4490931      -
# Gm37323                4583129      -
# ...                        ...    ...
# selection_hygromycinB        1      +
# selection_kanamycin          1      +
# selection_neomycin           1      +
# selection_puromycin          1      +
# selection_zeocin             1      +
#
# [31065 rows x 5 columns]

# %% [markdown]
# # QC

# %%
#checks if the gene name (var) starts with 'mt' or 'ribo' via string methods
e155.var['mt']= e155.var_names.str.startswith(("mt-"))
print(sum(e155.var['mt']))
# Out:
# 13

# %%
e155.var['ribo'] = e155.var_names.str.startswith(("Rps","Rpl"))
print(sum(e155.var['ribo']))
# Out:
# 105

# %%
e155.var
# Out:
#                                    Accession             Chromosome      End  \
# Xkr4                      ENSMUSG00000051951                      1  3671498
# Gm37381                   ENSMUSG00000102343                      1  3986215
# Rp1                       ENSMUSG00000025900                      1  4409241
# Sox17                     ENSMUSG00000025902                      1  4497354
# Gm37323                   ENSMUSG00000104328                      1  4586252
# ...                                      ...                    ...      ...
# selection_hygromycinB  selection_hygromycinB  selection_hygromycinB     1025
# selection_kanamycin      selection_kanamycin    selection_kanamycin      794
# selection_neomycin        selection_neomycin     selection_neomycin      815
# selection_puromycin      selection_puromycin    selection_puromycin      599
# selection_zeocin            selection_zeocin       selection_zeocin      374
#
#                          Start Strand     mt   ribo
# Xkr4                   3205901      -  False  False
# Gm37381                3905739      -  False  False
# Rp1                    3999557      -  False  False
# Sox17                  4490931      -  False  False
# Gm37323                4583129      -  False  False
# ...                        ...    ...    ...    ...
# selection_hygromycinB        1      +  False  False
# selection_kanamycin          1      +  False  False
# selection_neomycin           1      +  False  False
# selection_puromycin          1      +  False  False
# selection_zeocin             1      +  False  False
#
# [31065 rows x 7 columns]

# %%
sc.pp.calculate_qc_metrics(e155, qc_vars=['ribo', 'mt'], percent_top=None, log1p=False, inplace=True)

# %%
axs = sc.pl.violin(e155, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'pct_counts_ribo'],jitter=0.4, multi_panel=True)

# %%
sc.pl.scatter(e155, x='total_counts', y='n_genes_by_counts')

# %%
e155 = e155[e155.obs['total_counts'] < 18000, :]
e155 = e155[e155.obs['pct_counts_mt'] < 2.5, :]
# filter for percent ribo > 0.05
e155 = e155[e155.obs['pct_counts_ribo'] < 60, :]
axs = sc.pl.violin(e155, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'pct_counts_ribo'],jitter=0.4, multi_panel=True)

# %%
sc.pl.scatter(e155, x='total_counts', y='n_genes_by_counts')

# %%
sc.pp.calculate_qc_metrics(e155, qc_vars=['ribo', 'mt'], percent_top=None, log1p=False, inplace=True)

# %%
e155 = e155[e155.obs['n_genes_by_counts'] > 500, :]

# %% [markdown]
# # Remove genes we don't care about (ribo, malat, mito) and are expressed in less than 5 cells

# %%
sc.pp.filter_genes(e155, min_cells=5)


print("Number of cells: ",e155.n_obs)

#save a copy of anndata before normalization 
e155 = e155.copy()

##remove MT, ribo, and maltat reads since these reads are highly abundant, but not relevant to expirement
mito_genes = e155.var_names.str.startswith("mt-")
ribo_genes = e155.var_names.str.startswith(("Rps","Rpl"))
malat_gene = e155.var_names.str.startswith("Malat1")

remove = np.add(mito_genes, ribo_genes)
remove = np.add(remove, malat_gene)
keep = np.invert(remove)

print(len(remove))

print(np.count_nonzero(keep))
print(len(keep) - np.count_nonzero(keep))

e155 = e155[:,keep].copy()

print("Number of genes: ",e155.n_vars)
# Out:
# Number of cells:  1003
# 13049
# 12941
# 108
# Number of genes:  12941

# %% [markdown]
# # SCN using Qin's data to train
#
# Load in Qin's data

# %%
adTrain = sc.read_h5ad("C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/adJointDev_ALL_032322v2.h5ad")

# %%
adTrain.var_names_make_unique()

# %%
qDat = e155.copy()
qDat.var_names_make_unique()

# %%
genesTrain = adTrain.var_names
genesQuery = qDat.var_names
cgenes = genesTrain.intersection(genesQuery)
print(len(cgenes))

adTrain1 = adTrain[:,cgenes]
adQuery = qDat[:,cgenes].copy()
adTrain1 = adTrain1[~adTrain1.obs.index.duplicated()]
# Out:
# 12941

# %%
qDat.obs
# Out:
#                                      timepoint     ann1   level1   level2  \
# qb_E15-5_gdf:AAACCTGTCAACACTGx-3-0-0     e15.5    joint      SC3    SC3_B
# qb_E15-5_gdf:AAACGGGCATGTAGTCx-3-0-0     e15.5    joint      SC3    SC3_B
# qb_E15-5_gdf:AAACGGGCATTCCTCGx-3-0-0     e15.5    joint      SC3    SC3_B
# qb_E15-5_gdf:AAACGGGTCCAAGCCGx-3-0-0     e15.5    joint      SC3    SC3_B
# qb_E15-5_gdf:AAAGATGCAATGTAAGx-3-0-0     e15.5    joint      SC2    SC2_B
# ...                                        ...      ...      ...      ...
# qb_E15-5_gdf:TTATGCTTCACTCTTAx-3-0-1     e15.5   dermis   dermis   dermis
# qb_E15-5_gdf:TTCCCAGTCTCCGGTTx-3-0-1     e15.5   dermis   dermis   dermis
# qb_E15-5_gdf:TTCGAAGAGCAGATCGx-3-0-1     e15.5  myocyte  myocyte  myocyte
# qb_E15-5_gdf:TTGTAGGTCACCGGGTx-3-0-1     e15.5   dermis   dermis   dermis
# qb_E15-5_gdf:TTTGGTTAGATAGTCAx-3-0-1     e15.5    blood    blood    blood
#
#                                        level3 topLevel batch  \
# qb_E15-5_gdf:AAACCTGTCAACACTGx-3-0-0   SC3_B1      GLE     0
# qb_E15-5_gdf:AAACGGGCATGTAGTCx-3-0-0   SC3_B1      GLE     0
# qb_E15-5_gdf:AAACGGGCATTCCTCGx-3-0-0   SC3_B1      GLE     0
# qb_E15-5_gdf:AAACGGGTCCAAGCCGx-3-0-0   SC3_B1      GLE     0
# qb_E15-5_gdf:AAAGATGCAATGTAAGx-3-0-0   SC2_B1      GLE     0
# ...                                       ...      ...   ...
# qb_E15-5_gdf:TTATGCTTCACTCTTAx-3-0-1   dermis  non-GLE     1
# qb_E15-5_gdf:TTCCCAGTCTCCGGTTx-3-0-1   dermis  non-GLE     1
# qb_E15-5_gdf:TTCGAAGAGCAGATCGx-3-0-1  myocyte  non-GLE     1
# qb_E15-5_gdf:TTGTAGGTCACCGGGTx-3-0-1   dermis  non-GLE     1
# qb_E15-5_gdf:TTTGGTTAGATAGTCAx-3-0-1    blood  non-GLE     1
#
#                                       n_genes_by_counts  total_counts  \
# qb_E15-5_gdf:AAACCTGTCAACACTGx-3-0-0               1648        4089.0
# qb_E15-5_gdf:AAACGGGCATGTAGTCx-3-0-0               3172       10346.0
# qb_E15-5_gdf:AAACGGGCATTCCTCGx-3-0-0               3198        9217.0
# qb_E15-5_gdf:AAACGGGTCCAAGCCGx-3-0-0               3500       11401.0
# qb_E15-5_gdf:AAAGATGCAATGTAAGx-3-0-0               1279        3278.0
# ...                                                 ...           ...
# qb_E15-5_gdf:TTATGCTTCACTCTTAx-3-0-1               3078       12495.0
# qb_E15-5_gdf:TTCCCAGTCTCCGGTTx-3-0-1               3299       12002.0
# qb_E15-5_gdf:TTCGAAGAGCAGATCGx-3-0-1               2665       10317.0
# qb_E15-5_gdf:TTGTAGGTCACCGGGTx-3-0-1               2347        7399.0
# qb_E15-5_gdf:TTTGGTTAGATAGTCAx-3-0-1               1720        7530.0
#
#                                       total_counts_ribo  pct_counts_ribo  \
# qb_E15-5_gdf:AAACCTGTCAACACTGx-3-0-0             1116.0        27.292738
# qb_E15-5_gdf:AAACGGGCATGTAGTCx-3-0-0             2574.0        24.879179
# qb_E15-5_gdf:AAACGGGCATTCCTCGx-3-0-0             1614.0        17.511120
# qb_E15-5_gdf:AAACGGGTCCAAGCCGx-3-0-0             2413.0        21.164810
# qb_E15-5_gdf:AAAGATGCAATGTAAGx-3-0-0             1017.0        31.025017
# ...                                                 ...              ...
# qb_E15-5_gdf:TTATGCTTCACTCTTAx-3-0-1             4134.0        33.085232
# qb_E15-5_gdf:TTCCCAGTCTCCGGTTx-3-0-1             3282.0        27.345444
# qb_E15-5_gdf:TTCGAAGAGCAGATCGx-3-0-1             4100.0        39.740234
# qb_E15-5_gdf:TTGTAGGTCACCGGGTx-3-0-1             1913.0        25.854843
# qb_E15-5_gdf:TTTGGTTAGATAGTCAx-3-0-1             3674.0        48.791500
#
#                                       total_counts_mt  pct_counts_mt
# qb_E15-5_gdf:AAACCTGTCAACACTGx-3-0-0             20.0       0.489117
# qb_E15-5_gdf:AAACGGGCATGTAGTCx-3-0-0             85.0       0.821574
# qb_E15-5_gdf:AAACGGGCATTCCTCGx-3-0-0             96.0       1.041554
# qb_E15-5_gdf:AAACGGGTCCAAGCCGx-3-0-0            108.0       0.947285
# qb_E15-5_gdf:AAAGATGCAATGTAAGx-3-0-0             26.0       0.793167
# ...                                               ...            ...
# qb_E15-5_gdf:TTATGCTTCACTCTTAx-3-0-1             90.0       0.720288
# qb_E15-5_gdf:TTCCCAGTCTCCGGTTx-3-0-1             81.0       0.674888
# qb_E15-5_gdf:TTCGAAGAGCAGATCGx-3-0-1             95.0       0.920810
# qb_E15-5_gdf:TTGTAGGTCACCGGGTx-3-0-1             61.0       0.824436
# qb_E15-5_gdf:TTTGGTTAGATAGTCAx-3-0-1             94.0       1.248340
#
# [1003 rows x 13 columns]

# %%
qDat.var
# Out:
#                         Accession Chromosome       End     Start Strand  \
# Mrpl15         ENSMUSG00000033845          1   4785739   4773206      -
# Rgs20          ENSMUSG00000002459          1   5070285   4909576      -
# 4732440D04Rik  ENSMUSG00000090031          1   6215293   6209866      -
# Mybl1          ENSMUSG00000025912          1   9700209   9667415      -
# Vcpip1         ENSMUSG00000045210          1   9748382   9718622      -
# ...                           ...        ...       ...       ...    ...
# Ddx3y          ENSMUSG00000069045          Y   1286629   1260771      -
# Kdm5d          ENSMUSG00000056673          Y    956786    897788      +
# Eif2s3y        ENSMUSG00000069049          Y   1028847   1010543      +
# Gm29650        ENSMUSG00000099876          Y   1049134   1048393      +
# Gm47283        ENSMUSG00000096768          Y  90816464  90784738      +
#
#                   mt   ribo  n_cells_by_counts  mean_counts  \
# Mrpl15         False  False                 88     0.094716
# Rgs20          False  False                 10     0.011964
# 4732440D04Rik  False  False                  6     0.005982
# Mybl1          False  False                 30     0.034895
# Vcpip1         False  False                184     0.214357
# ...              ...    ...                ...          ...
# Ddx3y          False  False                501     0.796610
# Kdm5d          False  False                 25     0.025922
# Eif2s3y        False  False                271     0.342971
# Gm29650        False  False                 11     0.010967
# Gm47283        False  False                573     1.234297
#
#                pct_dropout_by_counts  total_counts  n_cells
# Mrpl15                     91.226321          95.0       88
# Rgs20                      99.002991          12.0       10
# 4732440D04Rik              99.401795           6.0        6
# Mybl1                      97.008973          35.0       30
# Vcpip1                     81.655035         215.0      184
# ...                              ...           ...      ...
# Ddx3y                      50.049850         799.0      501
# Kdm5d                      97.507478          26.0       25
# Eif2s3y                    72.981057         344.0      271
# Gm29650                    98.903290          11.0       11
# Gm47283                    42.871386        1238.0      573
#
# [12941 rows x 12 columns]

# %% [markdown]
# # Split training data into two to check classifer later

# %%
expTrain, expVal = pySCN.splitCommonAnnData(adTrain1, ncells=200,dLevel="level2")
# Out:
# SC3_A :
# 2451
# 3 :
# 251
# erythro :
# 6
# 7 (prog) :
# 51
# endothelial :
# 23
# 8 :
# 25
# SC2_B :
# 495
# 1 (chon) :
# 90
# SC1_A :
# 1791
# 9 (divi) :
# 141
# 5 (stro) :
# 633
# ncc :
# 78
# 3 (line) :
# 49
# SC2_A :
# 627
# dermis :
# 964
# 5 :
# 5
# myocyte :
# 1128
# 6 :
# 52
# 8 (prog) :
# 123
# blood :
# 286
# melanocyte :
# 15
# SC3_B :
# 1070
# SC1_B :
# 895
# 4 :
# 209
# 0 :
# 22
# 2 (liga) :
# 54
# 7 :
# 48
# 6 (stro) :
# 134
# 4 (synfib) :
# 26
# 2 :
# 354

# %% [markdown]
# # Train the classifer

# %%
[cgenesA, xpairs, tspRF] = pySCN.scn_train(expTrain, nTopGenes = 100, nRand = 100, nTrees = 1000, nTopGenePairs = 100, dLevel = "level2", stratify=True, limitToHVG=True)
# Out:
# HVG
# Matrix normalized
# There are  1584  classification genes
#
# 0
# 1 (chon)
# 2
# 2 (liga)
# 3
# 3 (line)
# 4
# 4 (synfib)
# 5
# 5 (stro)
# 6
# 6 (stro)
# 7
# 7 (prog)
# 8
# 8 (prog)
# 9 (divi)
# SC1_A
# SC1_B
# SC2_A
# SC2_B
# SC3_A
# SC3_B
# blood
# dermis
# endothelial
# erythro
# melanocyte
# myocyte
# ncc
# There are 2871 top gene pairs
#
# Finished pair transforming the data

# %%
adVal = pySCN.scn_classify(expVal, cgenesA, xpairs, tspRF, nrand = 0)

ax = sc.pl.heatmap(adVal, adVal.var_names.values, groupby='SCN_class', cmap='viridis', dendrogram=False, swap_axes=True)

# %%
adQd5 = pySCN.scn_classify(adQuery, cgenesA, xpairs, tspRF, nrand = 0)

# %%
adQuery.obs = pd.concat([adQuery.obs, adQd5.obs['SCN_class']], axis=1)

# %% [markdown]
# # count normalization

# %%
e155 = adQuery.copy()

# %%
e155.write_h5ad("C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/e155_SCN.h5ad")

# %%
adata = sc.read_h5ad("C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/e155_SCN.h5ad")

# %%
adata.raw = adata
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=4, min_disp=0.25)

# %%
sc.pp.scale(adata, max_value=10)

# %% [markdown]
# # PCA

# %%
sc.tl.pca(adata, svd_solver='arpack', use_highly_variable=True)
sc.pl.pca_variance_ratio(adata)

# %% [markdown]
# # fine neighbors

# %%
sc.pp.neighbors(adata)
sc.tl.leiden(adata, resolution =.3)
sc.tl.umap(adata, .25)

# %%
adata.obs
# Out:
#                                      timepoint     ann1   level1   level2  \
# qb_E15-5_gdf:AAACCTGTCAACACTGx-3-0-0     e15.5    joint      SC3    SC3_B
# qb_E15-5_gdf:AAACGGGCATGTAGTCx-3-0-0     e15.5    joint      SC3    SC3_B
# qb_E15-5_gdf:AAACGGGCATTCCTCGx-3-0-0     e15.5    joint      SC3    SC3_B
# qb_E15-5_gdf:AAACGGGTCCAAGCCGx-3-0-0     e15.5    joint      SC3    SC3_B
# qb_E15-5_gdf:AAAGATGCAATGTAAGx-3-0-0     e15.5    joint      SC2    SC2_B
# ...                                        ...      ...      ...      ...
# qb_E15-5_gdf:TTATGCTTCACTCTTAx-3-0-1     e15.5   dermis   dermis   dermis
# qb_E15-5_gdf:TTCCCAGTCTCCGGTTx-3-0-1     e15.5   dermis   dermis   dermis
# qb_E15-5_gdf:TTCGAAGAGCAGATCGx-3-0-1     e15.5  myocyte  myocyte  myocyte
# qb_E15-5_gdf:TTGTAGGTCACCGGGTx-3-0-1     e15.5   dermis   dermis   dermis
# qb_E15-5_gdf:TTTGGTTAGATAGTCAx-3-0-1     e15.5    blood    blood    blood
#
#                                        level3 topLevel batch  \
# qb_E15-5_gdf:AAACCTGTCAACACTGx-3-0-0   SC3_B1      GLE     0
# qb_E15-5_gdf:AAACGGGCATGTAGTCx-3-0-0   SC3_B1      GLE     0
# qb_E15-5_gdf:AAACGGGCATTCCTCGx-3-0-0   SC3_B1      GLE     0
# qb_E15-5_gdf:AAACGGGTCCAAGCCGx-3-0-0   SC3_B1      GLE     0
# qb_E15-5_gdf:AAAGATGCAATGTAAGx-3-0-0   SC2_B1      GLE     0
# ...                                       ...      ...   ...
# qb_E15-5_gdf:TTATGCTTCACTCTTAx-3-0-1   dermis  non-GLE     1
# qb_E15-5_gdf:TTCCCAGTCTCCGGTTx-3-0-1   dermis  non-GLE     1
# qb_E15-5_gdf:TTCGAAGAGCAGATCGx-3-0-1  myocyte  non-GLE     1
# qb_E15-5_gdf:TTGTAGGTCACCGGGTx-3-0-1   dermis  non-GLE     1
# qb_E15-5_gdf:TTTGGTTAGATAGTCAx-3-0-1    blood  non-GLE     1
#
#                                       n_genes_by_counts  total_counts  \
# qb_E15-5_gdf:AAACCTGTCAACACTGx-3-0-0               1648        4089.0
# qb_E15-5_gdf:AAACGGGCATGTAGTCx-3-0-0               3172       10346.0
# qb_E15-5_gdf:AAACGGGCATTCCTCGx-3-0-0               3198        9217.0
# qb_E15-5_gdf:AAACGGGTCCAAGCCGx-3-0-0               3500       11401.0
# qb_E15-5_gdf:AAAGATGCAATGTAAGx-3-0-0               1279        3278.0
# ...                                                 ...           ...
# qb_E15-5_gdf:TTATGCTTCACTCTTAx-3-0-1               3078       12495.0
# qb_E15-5_gdf:TTCCCAGTCTCCGGTTx-3-0-1               3299       12002.0
# qb_E15-5_gdf:TTCGAAGAGCAGATCGx-3-0-1               2665       10317.0
# qb_E15-5_gdf:TTGTAGGTCACCGGGTx-3-0-1               2347        7399.0
# qb_E15-5_gdf:TTTGGTTAGATAGTCAx-3-0-1               1720        7530.0
#
#                                       total_counts_ribo  pct_counts_ribo  \
# qb_E15-5_gdf:AAACCTGTCAACACTGx-3-0-0             1116.0        27.292738
# qb_E15-5_gdf:AAACGGGCATGTAGTCx-3-0-0             2574.0        24.879179
# qb_E15-5_gdf:AAACGGGCATTCCTCGx-3-0-0             1614.0        17.511120
# qb_E15-5_gdf:AAACGGGTCCAAGCCGx-3-0-0             2413.0        21.164810
# qb_E15-5_gdf:AAAGATGCAATGTAAGx-3-0-0             1017.0        31.025017
# ...                                                 ...              ...
# qb_E15-5_gdf:TTATGCTTCACTCTTAx-3-0-1             4134.0        33.085232
# qb_E15-5_gdf:TTCCCAGTCTCCGGTTx-3-0-1             3282.0        27.345444
# qb_E15-5_gdf:TTCGAAGAGCAGATCGx-3-0-1             4100.0        39.740234
# qb_E15-5_gdf:TTGTAGGTCACCGGGTx-3-0-1             1913.0        25.854843
# qb_E15-5_gdf:TTTGGTTAGATAGTCAx-3-0-1             3674.0        48.791500
#
#                                       total_counts_mt  pct_counts_mt  \
# qb_E15-5_gdf:AAACCTGTCAACACTGx-3-0-0             20.0       0.489117
# qb_E15-5_gdf:AAACGGGCATGTAGTCx-3-0-0             85.0       0.821574
# qb_E15-5_gdf:AAACGGGCATTCCTCGx-3-0-0             96.0       1.041554
# qb_E15-5_gdf:AAACGGGTCCAAGCCGx-3-0-0            108.0       0.947285
# qb_E15-5_gdf:AAAGATGCAATGTAAGx-3-0-0             26.0       0.793167
# ...                                               ...            ...
# qb_E15-5_gdf:TTATGCTTCACTCTTAx-3-0-1             90.0       0.720288
# qb_E15-5_gdf:TTCCCAGTCTCCGGTTx-3-0-1             81.0       0.674888
# qb_E15-5_gdf:TTCGAAGAGCAGATCGx-3-0-1             95.0       0.920810
# qb_E15-5_gdf:TTGTAGGTCACCGGGTx-3-0-1             61.0       0.824436
# qb_E15-5_gdf:TTTGGTTAGATAGTCAx-3-0-1             94.0       1.248340
#
#                                      SCN_class leiden
# qb_E15-5_gdf:AAACCTGTCAACACTGx-3-0-0     SC3_B      1
# qb_E15-5_gdf:AAACGGGCATGTAGTCx-3-0-0     SC3_B      1
# qb_E15-5_gdf:AAACGGGCATTCCTCGx-3-0-0     SC3_B      1
# qb_E15-5_gdf:AAACGGGTCCAAGCCGx-3-0-0     SC3_B      1
# qb_E15-5_gdf:AAAGATGCAATGTAAGx-3-0-0     SC2_B      0
# ...                                        ...    ...
# qb_E15-5_gdf:TTATGCTTCACTCTTAx-3-0-1    dermis      5
# qb_E15-5_gdf:TTCCCAGTCTCCGGTTx-3-0-1    dermis      5
# qb_E15-5_gdf:TTCGAAGAGCAGATCGx-3-0-1         4      4
# qb_E15-5_gdf:TTGTAGGTCACCGGGTx-3-0-1    dermis      5
# qb_E15-5_gdf:TTTGGTTAGATAGTCAx-3-0-1     blood      6
#
# [1003 rows x 15 columns]

# %%
sc.pl.umap(adata, color=['leiden', 'SCN_class'], palette=sc.pl.palettes.default_20, )
# Out:
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 20, categories length: 21. Some categories will have the same color.

# %%
adata.var_names
# Out:
# Index(['Mrpl15', 'Rgs20', '4732440D04Rik', 'Mybl1', 'Vcpip1', 'Snhg6', 'Tcf24',
#        'Cops5', 'Arfgef1', 'Cpa6',
#        ...
#        'Gpm6b', 'Trappc2', 'Arhgap6', 'Gm21887', 'Uty', 'Ddx3y', 'Kdm5d',
#        'Eif2s3y', 'Gm29650', 'Gm47283'],
#       dtype='object', length=12941)

# %%
adata.obs["SCN_class"].value_counts()
# Out:
# SC2_B          425
# SC3_B          249
# SC2_A           83
# myocyte         78
# SC3_A           50
# dermis          42
# blood           23
# 4               12
# 5 (stro)        11
# 2 (liga)         6
# 1 (chon)         5
# 9 (divi)         5
# endothelial      3
# 7                2
# melanocyte       2
# ncc              2
# SC1_A            1
# 7 (prog)         1
# erythro          1
# 3 (line)         1
# rand             1
# Name: SCN_class, dtype: int64

# %%
adata = adata[~(adata.obs["SCN_class"] == "SC1_A")]
adata = adata[~(adata.obs["SCN_class"] == "7 (prog)")]
adata = adata[~(adata.obs["SCN_class"] == "3 (line)")]
adata = adata[~(adata.obs["SCN_class"] == "rand")]
adata = adata[~(adata.obs["SCN_class"] == "erythro")]
adata.obs["SCN_class"].value_counts()
# Out:
# SC2_B          425
# SC3_B          249
# SC2_A           83
# myocyte         78
# SC3_A           50
# dermis          42
# blood           23
# 4               12
# 5 (stro)        11
# 2 (liga)         6
# 1 (chon)         5
# 9 (divi)         5
# endothelial      3
# 7                2
# melanocyte       2
# ncc              2
# Name: SCN_class, dtype: int64

# %%
adata.obs['SCN_class'] == "SC1_A"
indicator = adata.obs["SCN_class"] == "SC1_A"
adata_SC1_A = adata [indicator,:]

adata_SC1_A.var['total_expression'] = adata_SC1_A.X.sum(0)
adata_SC1_A.var['total_expression'].nlargest(100) 
top_expression_genes_adata_SC1_A = adata_SC1_A.var['total_expression'].nlargest(100)
top_expression_genes_adata_SC1_A_df = pd.DataFrame(top_expression_genes_adata_SC1_A)
top_expression_genes_adata_SC1_A_df.to_excel('C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/excel/SCN_cluster/e155_highly_expr_genes_SC1_A.xlsx', index=True)

# %%
adata.obs['SCN_class'] == "SC2_A"
indicator = adata.obs["SCN_class"] == "SC2_A"
adata_SC2_A = adata [indicator,:]

adata_SC2_A.var['total_expression'] = adata_SC2_A.X.sum(0)
adata_SC2_A.var['total_expression'].nlargest(100) 
top_expression_genes_adata_SC2_A = adata_SC2_A.var['total_expression'].nlargest(100)
top_expression_genes_adata_SC2_A_df = pd.DataFrame(top_expression_genes_adata_SC2_A)
top_expression_genes_adata_SC2_A_df.to_excel('C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/excel/SCN_cluster/e155_highly_expr_genes_SC2_A.xlsx', index=True)

# %%
adata.obs['SCN_class'] == "SC2_B"
indicator = adata.obs["SCN_class"] == "SC2_B"
adata_SC2_B = adata [indicator,:]

adata_SC2_B.var['total_expression'] = adata_SC2_B.X.sum(0)
adata_SC2_B.var['total_expression'].nlargest(100) 
top_expression_genes_adata_SC2_B = adata_SC2_B.var['total_expression'].nlargest(100)
top_expression_genes_adata_SC2_B_df = pd.DataFrame(top_expression_genes_adata_SC2_B)
top_expression_genes_adata_SC2_B_df.to_excel('C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/excel/SCN_cluster/e155_highly_expr_genes_SC2_B.xlsx', index=True)

# %%
adata.obs['SCN_class'] == "SC3_A"
indicator = adata.obs["SCN_class"] == "SC3_A"
adata_SC3_A = adata [indicator,:]

adata_SC3_A.var['total_expression'] = adata_SC3_A.X.sum(0)
adata_SC3_A.var['total_expression'].nlargest(100) 
top_expression_genes_adata_SC3_A = adata_SC3_A.var['total_expression'].nlargest(100)
top_expression_genes_adata_SC3_A_df = pd.DataFrame(top_expression_genes_adata_SC3_A)
top_expression_genes_adata_SC3_A_df.to_excel('C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/excel/SCN_cluster/e155_highly_expr_genes_SC3_A.xlsx', index=True)

# %%
adata.obs['SCN_class'] == "SC3_B"
indicator = adata.obs["SCN_class"] == "SC3_B"
adata_SC3_B = adata [indicator,:]

adata_SC3_B.var['total_expression'] = adata_SC3_B.X.sum(0)
adata_SC3_B.var['total_expression'].nlargest(100) 
top_expression_genes_adata_SC3_B = adata_SC3_B.var['total_expression'].nlargest(100)
top_expression_genes_adata_SC3_B_df = pd.DataFrame(top_expression_genes_adata_SC3_B)
top_expression_genes_adata_SC3_B_df.to_excel('C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/excel/SCN_cluster/e155_highly_expr_genes_SC3_B.xlsx', index=True)
