# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
import scipy as sp
import numpy as np
import warnings
import pySingleCellNet as pySCN

warnings.filterwarnings('ignore')
sc.settings.set_figure_params(dpi=80)
# Out:
# C:\Users\yeaji\anaconda3\Lib\site-packages\umap\distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# C:\Users\yeaji\anaconda3\Lib\site-packages\umap\distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# C:\Users\yeaji\anaconda3\Lib\site-packages\umap\distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# C:\Users\yeaji\anaconda3\Lib\site-packages\umap\umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %%
e145 = sc.read("C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/adJointDev_ALL_032322v2.h5ad")

# %%
e145.obs['timepoint']=="E14.5"
# Out:
# qb_E12-5_gdf:AAACCTGAGGCGTACAx-0-0-0    False
# qb_E12-5_gdf:AAACCTGCACTGCCAGx-0-0-0    False
# qb_E12-5_gdf:AAACCTGGTGAGTGACx-0-0-0    False
# qb_E12-5_gdf:AAACCTGGTTGCCTCTx-0-0-0    False
# qb_E12-5_gdf:AAACCTGTCGAGAACGx-0-0-0    False
#                                         ...
# qb_E17-5_gdf:TTGCGTCGTGTGGTTTx-1-1      False
# qb_E17-5_gdf:TTTGTCACATCCCACTx-1-1      False
# qb_E17-5_gdf:TTGGCAATCACAACGTx-1-1      False
# qb_E17-5_gdf:TTTGGTTTCGACGGAAx-1-1      False
# qb_E17-5_gdf:TTGGCAAAGTGGGCTAx-1-1      False
# Name: timepoint, Length: 12096, dtype: bool

# %%
indicator = e145.obs["timepoint"]=="e14.5"
e145 = e145[indicator,:]

# %%
e145.write_h5ad("C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/e145_raw.h5ad")

# %%
e145
# Out:
# View of AnnData object with n_obs × n_vars = 1732 × 31065
#     obs: 'timepoint', 'ann1', 'level1', 'level2', 'level3', 'topLevel', 'batch'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'

# %%
e145.obs
# Out:
#                                      timepoint     ann1   level1   level2  \
# qb_E14-5_gdf:AAACCTGAGCGATGACx-2-0-0     e14.5    joint      SC3    SC3_B
# qb_E14-5_gdf:AAACCTGGTGCCTGCAx-2-0-0     e14.5    joint      SC3    SC3_B
# qb_E14-5_gdf:AAACCTGTCAGAAATGx-2-0-0     e14.5    joint      SC2    SC2_A
# qb_E14-5_gdf:AAACGGGAGAAGGTTTx-2-0-0     e14.5    joint      SC3    SC3_B
# qb_E14-5_gdf:AAACGGGGTCATTAGCx-2-0-0     e14.5    joint      SC2    SC2_A
# ...                                        ...      ...      ...      ...
# qb_E14-5_gdf:TTTGCGCAGACTAAGTx-2-0-1     e14.5  myocyte  myocyte  myocyte
# qb_E14-5_gdf:TTTGCGCAGTGACTCTx-2-0-1     e14.5   dermis   dermis   dermis
# qb_E14-5_gdf:TTTGGTTTCATGTCCCx-2-0-1     e14.5  myocyte  myocyte  myocyte
# qb_E14-5_gdf:TTTGTCAAGCCGCCTAx-2-0-1     e14.5   dermis   dermis   dermis
# qb_E14-5_gdf:TTTGTCAAGTCATGCTx-2-0-1     e14.5  myocyte  myocyte  myocyte
#
#                                        level3 topLevel batch
# qb_E14-5_gdf:AAACCTGAGCGATGACx-2-0-0   SC3_B1      GLE     0
# qb_E14-5_gdf:AAACCTGGTGCCTGCAx-2-0-0   SC3_B2      GLE     0
# qb_E14-5_gdf:AAACCTGTCAGAAATGx-2-0-0   SC2_A2      GLE     0
# qb_E14-5_gdf:AAACGGGAGAAGGTTTx-2-0-0   SC3_B1      GLE     0
# qb_E14-5_gdf:AAACGGGGTCATTAGCx-2-0-0   SC2_A2      GLE     0
# ...                                       ...      ...   ...
# qb_E14-5_gdf:TTTGCGCAGACTAAGTx-2-0-1  myocyte  non-GLE     1
# qb_E14-5_gdf:TTTGCGCAGTGACTCTx-2-0-1   dermis  non-GLE     1
# qb_E14-5_gdf:TTTGGTTTCATGTCCCx-2-0-1  myocyte  non-GLE     1
# qb_E14-5_gdf:TTTGTCAAGCCGCCTAx-2-0-1   dermis  non-GLE     1
# qb_E14-5_gdf:TTTGTCAAGTCATGCTx-2-0-1  myocyte  non-GLE     1
#
# [1732 rows x 7 columns]

# %%
e145.obs_names
# Out:
# Index(['qb_E14-5_gdf:AAACCTGAGCGATGACx-2-0-0',
#        'qb_E14-5_gdf:AAACCTGGTGCCTGCAx-2-0-0',
#        'qb_E14-5_gdf:AAACCTGTCAGAAATGx-2-0-0',
#        'qb_E14-5_gdf:AAACGGGAGAAGGTTTx-2-0-0',
#        'qb_E14-5_gdf:AAACGGGGTCATTAGCx-2-0-0',
#        'qb_E14-5_gdf:AAAGATGAGACGCTTTx-2-0-0',
#        'qb_E14-5_gdf:AAAGATGAGCTGCAAGx-2-0-0',
#        'qb_E14-5_gdf:AAAGCAAAGAGGTTGCx-2-0-0',
#        'qb_E14-5_gdf:AAAGCAAGTGCGCTTGx-2-0-0',
#        'qb_E14-5_gdf:AAAGCAATCGAATGGGx-2-0-0',
#        ...
#        'qb_E14-5_gdf:TTTACTGGTGAGTGACx-2-0-1',
#        'qb_E14-5_gdf:TTTCCTCAGGTTCCTAx-2-0-1',
#        'qb_E14-5_gdf:TTTCCTCCAAAGGTGCx-2-0-1',
#        'qb_E14-5_gdf:TTTCCTCCAAGCTGAGx-2-0-1',
#        'qb_E14-5_gdf:TTTCCTCCAATGGAGCx-2-0-1',
#        'qb_E14-5_gdf:TTTGCGCAGACTAAGTx-2-0-1',
#        'qb_E14-5_gdf:TTTGCGCAGTGACTCTx-2-0-1',
#        'qb_E14-5_gdf:TTTGGTTTCATGTCCCx-2-0-1',
#        'qb_E14-5_gdf:TTTGTCAAGCCGCCTAx-2-0-1',
#        'qb_E14-5_gdf:TTTGTCAAGTCATGCTx-2-0-1'],
#       dtype='object', length=1732)

# %%
e145.var
# Out:
#                                    Accession             Chromosome      End  \
# Xkr4                      ENSMUSG00000051951                      1  3671498
# Gm37381                   ENSMUSG00000102343                      1  3986215
# Rp1                       ENSMUSG00000025900                      1  4409241
# Sox17                     ENSMUSG00000025902                      1  4497354
# Gm37323                   ENSMUSG00000104328                      1  4586252
# ...                                      ...                    ...      ...
# selection_hygromycinB  selection_hygromycinB  selection_hygromycinB     1025
# selection_kanamycin      selection_kanamycin    selection_kanamycin      794
# selection_neomycin        selection_neomycin     selection_neomycin      815
# selection_puromycin      selection_puromycin    selection_puromycin      599
# selection_zeocin            selection_zeocin       selection_zeocin      374
#
#                          Start Strand
# Xkr4                   3205901      -
# Gm37381                3905739      -
# Rp1                    3999557      -
# Sox17                  4490931      -
# Gm37323                4583129      -
# ...                        ...    ...
# selection_hygromycinB        1      +
# selection_kanamycin          1      +
# selection_neomycin           1      +
# selection_puromycin          1      +
# selection_zeocin             1      +
#
# [31065 rows x 5 columns]

# %% [markdown]
# # QC

# %%
#checks if the gene name (var) starts with 'mt' or 'ribo' via string methods
e145.var['mt']= e145.var_names.str.startswith(("mt-"))
print(sum(e145.var['mt']))
# Out:
# 13

# %%
e145.var['ribo'] = e145.var_names.str.startswith(("Rps","Rpl"))
print(sum(e145.var['ribo']))
# Out:
# 105

# %%
e145.var
# Out:
#                                    Accession             Chromosome      End  \
# Xkr4                      ENSMUSG00000051951                      1  3671498
# Gm37381                   ENSMUSG00000102343                      1  3986215
# Rp1                       ENSMUSG00000025900                      1  4409241
# Sox17                     ENSMUSG00000025902                      1  4497354
# Gm37323                   ENSMUSG00000104328                      1  4586252
# ...                                      ...                    ...      ...
# selection_hygromycinB  selection_hygromycinB  selection_hygromycinB     1025
# selection_kanamycin      selection_kanamycin    selection_kanamycin      794
# selection_neomycin        selection_neomycin     selection_neomycin      815
# selection_puromycin      selection_puromycin    selection_puromycin      599
# selection_zeocin            selection_zeocin       selection_zeocin      374
#
#                          Start Strand     mt   ribo
# Xkr4                   3205901      -  False  False
# Gm37381                3905739      -  False  False
# Rp1                    3999557      -  False  False
# Sox17                  4490931      -  False  False
# Gm37323                4583129      -  False  False
# ...                        ...    ...    ...    ...
# selection_hygromycinB        1      +  False  False
# selection_kanamycin          1      +  False  False
# selection_neomycin           1      +  False  False
# selection_puromycin          1      +  False  False
# selection_zeocin             1      +  False  False
#
# [31065 rows x 7 columns]

# %%
sc.pp.calculate_qc_metrics(e145, qc_vars=['ribo', 'mt'], percent_top=None, log1p=False, inplace=True)

# %%
axs = sc.pl.violin(e145, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'pct_counts_ribo'],jitter=0.4, multi_panel=True)

# %%
sc.pl.scatter(e145, x='total_counts', y='n_genes_by_counts')

# %%
e145 = e145[e145.obs['total_counts'] < 18000, :]
e145 = e145[e145.obs['pct_counts_mt'] < 2.5, :]
# filter for percent ribo > 0.05
e145 = e145[e145.obs['pct_counts_ribo'] < 60, :]
axs = sc.pl.violin(e145, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'pct_counts_ribo'],jitter=0.4, multi_panel=True)

# %%
sc.pl.scatter(e145, x='total_counts', y='n_genes_by_counts')

# %%
sc.pp.calculate_qc_metrics(e145, qc_vars=['ribo', 'mt'], percent_top=None, log1p=False, inplace=True)

# %%
e145 = e145[e145.obs['n_genes_by_counts'] > 500, :]

# %% [markdown]
# # Remove genes we don't care about (ribo, malat, mito) and are expressed in less than 5 cells

# %%
sc.pp.filter_genes(e145, min_cells=5)


print("Number of cells: ",e145.n_obs)

#save a copy of anndata before normalization 
e145 = e145.copy()

##remove MT, ribo, and maltat reads since these reads are highly abundant, but not relevant to expirement
mito_genes = e145.var_names.str.startswith("mt-")
ribo_genes = e145.var_names.str.startswith(("Rps","Rpl"))
malat_gene = e145.var_names.str.startswith("Malat1")

remove = np.add(mito_genes, ribo_genes)
remove = np.add(remove, malat_gene)
keep = np.invert(remove)

print(len(remove))

print(np.count_nonzero(keep))
print(len(keep) - np.count_nonzero(keep))

e145 = e145[:,keep].copy()

print("Number of genes: ",e145.n_vars)
# Out:
# Number of cells:  1732
# 13728
# 13621
# 107
# Number of genes:  13621

# %% [markdown]
# # SCN using Qin's data to train
#
# Load in Qin's data

# %%
adTrain = sc.read_h5ad("C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/adJointDev_ALL_032322v2.h5ad")

# %%
adTrain.var_names_make_unique()

# %%
qDat = e145.copy()
qDat.var_names_make_unique()

# %%
genesTrain = adTrain.var_names
genesQuery = qDat.var_names
cgenes = genesTrain.intersection(genesQuery)
print(len(cgenes))

adTrain1 = adTrain[:,cgenes]
adQuery = qDat[:,cgenes].copy()
adTrain1 = adTrain1[~adTrain1.obs.index.duplicated()]
# Out:
# 13621

# %%
qDat.obs
# Out:
#                                      timepoint     ann1   level1   level2  \
# qb_E14-5_gdf:AAACCTGAGCGATGACx-2-0-0     e14.5    joint      SC3    SC3_B
# qb_E14-5_gdf:AAACCTGGTGCCTGCAx-2-0-0     e14.5    joint      SC3    SC3_B
# qb_E14-5_gdf:AAACCTGTCAGAAATGx-2-0-0     e14.5    joint      SC2    SC2_A
# qb_E14-5_gdf:AAACGGGAGAAGGTTTx-2-0-0     e14.5    joint      SC3    SC3_B
# qb_E14-5_gdf:AAACGGGGTCATTAGCx-2-0-0     e14.5    joint      SC2    SC2_A
# ...                                        ...      ...      ...      ...
# qb_E14-5_gdf:TTTGCGCAGACTAAGTx-2-0-1     e14.5  myocyte  myocyte  myocyte
# qb_E14-5_gdf:TTTGCGCAGTGACTCTx-2-0-1     e14.5   dermis   dermis   dermis
# qb_E14-5_gdf:TTTGGTTTCATGTCCCx-2-0-1     e14.5  myocyte  myocyte  myocyte
# qb_E14-5_gdf:TTTGTCAAGCCGCCTAx-2-0-1     e14.5   dermis   dermis   dermis
# qb_E14-5_gdf:TTTGTCAAGTCATGCTx-2-0-1     e14.5  myocyte  myocyte  myocyte
#
#                                        level3 topLevel batch  \
# qb_E14-5_gdf:AAACCTGAGCGATGACx-2-0-0   SC3_B1      GLE     0
# qb_E14-5_gdf:AAACCTGGTGCCTGCAx-2-0-0   SC3_B2      GLE     0
# qb_E14-5_gdf:AAACCTGTCAGAAATGx-2-0-0   SC2_A2      GLE     0
# qb_E14-5_gdf:AAACGGGAGAAGGTTTx-2-0-0   SC3_B1      GLE     0
# qb_E14-5_gdf:AAACGGGGTCATTAGCx-2-0-0   SC2_A2      GLE     0
# ...                                       ...      ...   ...
# qb_E14-5_gdf:TTTGCGCAGACTAAGTx-2-0-1  myocyte  non-GLE     1
# qb_E14-5_gdf:TTTGCGCAGTGACTCTx-2-0-1   dermis  non-GLE     1
# qb_E14-5_gdf:TTTGGTTTCATGTCCCx-2-0-1  myocyte  non-GLE     1
# qb_E14-5_gdf:TTTGTCAAGCCGCCTAx-2-0-1   dermis  non-GLE     1
# qb_E14-5_gdf:TTTGTCAAGTCATGCTx-2-0-1  myocyte  non-GLE     1
#
#                                       n_genes_by_counts  total_counts  \
# qb_E14-5_gdf:AAACCTGAGCGATGACx-2-0-0               1662        4384.0
# qb_E14-5_gdf:AAACCTGGTGCCTGCAx-2-0-0               1407        3466.0
# qb_E14-5_gdf:AAACCTGTCAGAAATGx-2-0-0               2131        6858.0
# qb_E14-5_gdf:AAACGGGAGAAGGTTTx-2-0-0               2285        7068.0
# qb_E14-5_gdf:AAACGGGGTCATTAGCx-2-0-0               1244        3168.0
# ...                                                 ...           ...
# qb_E14-5_gdf:TTTGCGCAGACTAAGTx-2-0-1               2225        9152.0
# qb_E14-5_gdf:TTTGCGCAGTGACTCTx-2-0-1               1962        4607.0
# qb_E14-5_gdf:TTTGGTTTCATGTCCCx-2-0-1               2428       10365.0
# qb_E14-5_gdf:TTTGTCAAGCCGCCTAx-2-0-1               3411       13578.0
# qb_E14-5_gdf:TTTGTCAAGTCATGCTx-2-0-1               2310        8516.0
#
#                                       total_counts_ribo  pct_counts_ribo  \
# qb_E14-5_gdf:AAACCTGAGCGATGACx-2-0-0             1361.0        31.044706
# qb_E14-5_gdf:AAACCTGGTGCCTGCAx-2-0-0             1174.0        33.871899
# qb_E14-5_gdf:AAACCTGTCAGAAATGx-2-0-0             2517.0        36.701660
# qb_E14-5_gdf:AAACGGGAGAAGGTTTx-2-0-0             1981.0        28.027731
# qb_E14-5_gdf:AAACGGGGTCATTAGCx-2-0-0             1127.0        35.574497
# ...                                                 ...              ...
# qb_E14-5_gdf:TTTGCGCAGACTAAGTx-2-0-1             4255.0        46.492569
# qb_E14-5_gdf:TTTGCGCAGTGACTCTx-2-0-1             1111.0        24.115477
# qb_E14-5_gdf:TTTGGTTTCATGTCCCx-2-0-1             4539.0        43.791607
# qb_E14-5_gdf:TTTGTCAAGCCGCCTAx-2-0-1             3979.0        29.304758
# qb_E14-5_gdf:TTTGTCAAGTCATGCTx-2-0-1             3198.0        37.552841
#
#                                       total_counts_mt  pct_counts_mt
# qb_E14-5_gdf:AAACCTGAGCGATGACx-2-0-0             26.0       0.593066
# qb_E14-5_gdf:AAACCTGGTGCCTGCAx-2-0-0             42.0       1.211771
# qb_E14-5_gdf:AAACCTGTCAGAAATGx-2-0-0             48.0       0.699913
# qb_E14-5_gdf:AAACGGGAGAAGGTTTx-2-0-0             18.0       0.254669
# qb_E14-5_gdf:AAACGGGGTCATTAGCx-2-0-0             37.0       1.167929
# ...                                               ...            ...
# qb_E14-5_gdf:TTTGCGCAGACTAAGTx-2-0-1            151.0       1.649913
# qb_E14-5_gdf:TTTGCGCAGTGACTCTx-2-0-1             71.0       1.541133
# qb_E14-5_gdf:TTTGGTTTCATGTCCCx-2-0-1            159.0       1.534009
# qb_E14-5_gdf:TTTGTCAAGCCGCCTAx-2-0-1             73.0       0.537634
# qb_E14-5_gdf:TTTGTCAAGTCATGCTx-2-0-1            110.0       1.291686
#
# [1732 rows x 13 columns]

# %%
qDat.var
# Out:
#                   Accession Chromosome       End     Start Strand     mt  \
# Sox17    ENSMUSG00000025902          1   4497354   4490931      -  False
# Mrpl15   ENSMUSG00000033845          1   4785739   4773206      -  False
# Mybl1    ENSMUSG00000025912          1   9700209   9667415      -  False
# Vcpip1   ENSMUSG00000045210          1   9748382   9718622      -  False
# Snhg6    ENSMUSG00000098234          1   9944118   9941959      -  False
# ...                     ...        ...       ...       ...    ...    ...
# Ddx3y    ENSMUSG00000069045          Y   1286629   1260771      -  False
# Kdm5d    ENSMUSG00000056673          Y    956786    897788      +  False
# Eif2s3y  ENSMUSG00000069049          Y   1028847   1010543      +  False
# Gm29650  ENSMUSG00000099876          Y   1049134   1048393      +  False
# Gm47283  ENSMUSG00000096768          Y  90816464  90784738      +  False
#
#           ribo  n_cells_by_counts  mean_counts  pct_dropout_by_counts  \
# Sox17    False                  5     0.012125              99.711316
# Mrpl15   False                260     0.174942              84.988453
# Mybl1    False                 18     0.010393              98.960739
# Vcpip1   False                200     0.129908              88.452656
# Snhg6    False               1396     2.251732              19.399538
# ...        ...                ...          ...                    ...
# Ddx3y    False                907     0.837182              47.632794
# Kdm5d    False                  9     0.005774              99.480370
# Eif2s3y  False                560     0.400693              67.667436
# Gm29650  False                 10     0.005774              99.422633
# Gm47283  False               1202     1.848730              30.600462
#
#          total_counts  n_cells
# Sox17            21.0        5
# Mrpl15          303.0      260
# Mybl1            18.0       18
# Vcpip1          225.0      200
# Snhg6          3900.0     1396
# ...               ...      ...
# Ddx3y          1450.0      907
# Kdm5d            10.0        9
# Eif2s3y         694.0      560
# Gm29650          10.0       10
# Gm47283        3202.0     1202
#
# [13621 rows x 12 columns]

# %% [markdown]
# # Split training data into two to check classifer later

# %%
expTrain, expVal = pySCN.splitCommonAnnData(adTrain1, ncells=200,dLevel="level2")
# Out:
# 3 (line) :
# 49
# ncc :
# 78
# 6 :
# 52
# endothelial :
# 23
# erythro :
# 6
# SC3_A :
# 2451
# 1 (chon) :
# 90
# 4 :
# 209
# 7 (prog) :
# 51
# blood :
# 286
# SC2_A :
# 627
# 4 (synfib) :
# 26
# 5 (stro) :
# 633
# melanocyte :
# 15
# 8 (prog) :
# 123
# SC1_B :
# 895
# 3 :
# 251
# 9 (divi) :
# 141
# 0 :
# 22
# SC2_B :
# 495
# 2 :
# 354
# SC1_A :
# 1791
# 6 (stro) :
# 134
# SC3_B :
# 1070
# 2 (liga) :
# 54
# dermis :
# 964
# 8 :
# 25
# myocyte :
# 1128
# 5 :
# 5
# 7 :
# 48

# %% [markdown]
# # Train the classifer

# %%
[cgenesA, xpairs, tspRF] = pySCN.scn_train(expTrain, nTopGenes = 100, nRand = 100, nTrees = 1000, nTopGenePairs = 100, dLevel = "level2", stratify=True, limitToHVG=True)
# Out:
# HVG
# Matrix normalized
# There are  1615  classification genes
#
# 0
# 1 (chon)
# 2
# 2 (liga)
# 3
# 3 (line)
# 4
# 4 (synfib)
# 5
# 5 (stro)
# 6
# 6 (stro)
# 7
# 7 (prog)
# 8
# 8 (prog)
# 9 (divi)
# SC1_A
# SC1_B
# SC2_A
# SC2_B
# SC3_A
# SC3_B
# blood
# dermis
# endothelial
# erythro
# melanocyte
# myocyte
# ncc
# There are 2886 top gene pairs
#
# Finished pair transforming the data

# %%
adVal = pySCN.scn_classify(expVal, cgenesA, xpairs, tspRF, nrand = 0)

ax = sc.pl.heatmap(adVal, adVal.var_names.values, groupby='SCN_class', cmap='viridis', dendrogram=False, swap_axes=True)

# %%
adQd5 = pySCN.scn_classify(adQuery, cgenesA, xpairs, tspRF, nrand = 0)

# %%
adQuery.obs = pd.concat([adQuery.obs, adQd5.obs['SCN_class']], axis=1)

# %% [markdown]
# # count normalization

# %%
e145 = adQuery.copy()

# %%
e145.write_h5ad("C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/e145_SCN.h5ad")

# %%
adata = sc.read_h5ad("C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/e145_SCN.h5ad")

# %%
adata.raw = adata
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=4, min_disp=0.25)

# %%
sc.pp.scale(adata, max_value=10)

# %% [markdown]
# # PCA

# %%
sc.tl.pca(adata, svd_solver='arpack', use_highly_variable=True)
sc.pl.pca_variance_ratio(adata)

# %% [markdown]
# # fine neighbors

# %%
sc.pp.neighbors(adata)
sc.tl.leiden(adata, resolution =.3)
sc.tl.umap(adata, .25)

# %%
adata.obs
# Out:
#                                      timepoint     ann1   level1   level2  \
# qb_E14-5_gdf:AAACCTGAGCGATGACx-2-0-0     e14.5    joint      SC3    SC3_B
# qb_E14-5_gdf:AAACCTGGTGCCTGCAx-2-0-0     e14.5    joint      SC3    SC3_B
# qb_E14-5_gdf:AAACCTGTCAGAAATGx-2-0-0     e14.5    joint      SC2    SC2_A
# qb_E14-5_gdf:AAACGGGAGAAGGTTTx-2-0-0     e14.5    joint      SC3    SC3_B
# qb_E14-5_gdf:AAACGGGGTCATTAGCx-2-0-0     e14.5    joint      SC2    SC2_A
# ...                                        ...      ...      ...      ...
# qb_E14-5_gdf:TTTGCGCAGACTAAGTx-2-0-1     e14.5  myocyte  myocyte  myocyte
# qb_E14-5_gdf:TTTGCGCAGTGACTCTx-2-0-1     e14.5   dermis   dermis   dermis
# qb_E14-5_gdf:TTTGGTTTCATGTCCCx-2-0-1     e14.5  myocyte  myocyte  myocyte
# qb_E14-5_gdf:TTTGTCAAGCCGCCTAx-2-0-1     e14.5   dermis   dermis   dermis
# qb_E14-5_gdf:TTTGTCAAGTCATGCTx-2-0-1     e14.5  myocyte  myocyte  myocyte
#
#                                        level3 topLevel batch  \
# qb_E14-5_gdf:AAACCTGAGCGATGACx-2-0-0   SC3_B1      GLE     0
# qb_E14-5_gdf:AAACCTGGTGCCTGCAx-2-0-0   SC3_B2      GLE     0
# qb_E14-5_gdf:AAACCTGTCAGAAATGx-2-0-0   SC2_A2      GLE     0
# qb_E14-5_gdf:AAACGGGAGAAGGTTTx-2-0-0   SC3_B1      GLE     0
# qb_E14-5_gdf:AAACGGGGTCATTAGCx-2-0-0   SC2_A2      GLE     0
# ...                                       ...      ...   ...
# qb_E14-5_gdf:TTTGCGCAGACTAAGTx-2-0-1  myocyte  non-GLE     1
# qb_E14-5_gdf:TTTGCGCAGTGACTCTx-2-0-1   dermis  non-GLE     1
# qb_E14-5_gdf:TTTGGTTTCATGTCCCx-2-0-1  myocyte  non-GLE     1
# qb_E14-5_gdf:TTTGTCAAGCCGCCTAx-2-0-1   dermis  non-GLE     1
# qb_E14-5_gdf:TTTGTCAAGTCATGCTx-2-0-1  myocyte  non-GLE     1
#
#                                       n_genes_by_counts  total_counts  \
# qb_E14-5_gdf:AAACCTGAGCGATGACx-2-0-0               1662        4384.0
# qb_E14-5_gdf:AAACCTGGTGCCTGCAx-2-0-0               1407        3466.0
# qb_E14-5_gdf:AAACCTGTCAGAAATGx-2-0-0               2131        6858.0
# qb_E14-5_gdf:AAACGGGAGAAGGTTTx-2-0-0               2285        7068.0
# qb_E14-5_gdf:AAACGGGGTCATTAGCx-2-0-0               1244        3168.0
# ...                                                 ...           ...
# qb_E14-5_gdf:TTTGCGCAGACTAAGTx-2-0-1               2225        9152.0
# qb_E14-5_gdf:TTTGCGCAGTGACTCTx-2-0-1               1962        4607.0
# qb_E14-5_gdf:TTTGGTTTCATGTCCCx-2-0-1               2428       10365.0
# qb_E14-5_gdf:TTTGTCAAGCCGCCTAx-2-0-1               3411       13578.0
# qb_E14-5_gdf:TTTGTCAAGTCATGCTx-2-0-1               2310        8516.0
#
#                                       total_counts_ribo  pct_counts_ribo  \
# qb_E14-5_gdf:AAACCTGAGCGATGACx-2-0-0             1361.0        31.044706
# qb_E14-5_gdf:AAACCTGGTGCCTGCAx-2-0-0             1174.0        33.871899
# qb_E14-5_gdf:AAACCTGTCAGAAATGx-2-0-0             2517.0        36.701660
# qb_E14-5_gdf:AAACGGGAGAAGGTTTx-2-0-0             1981.0        28.027731
# qb_E14-5_gdf:AAACGGGGTCATTAGCx-2-0-0             1127.0        35.574497
# ...                                                 ...              ...
# qb_E14-5_gdf:TTTGCGCAGACTAAGTx-2-0-1             4255.0        46.492569
# qb_E14-5_gdf:TTTGCGCAGTGACTCTx-2-0-1             1111.0        24.115477
# qb_E14-5_gdf:TTTGGTTTCATGTCCCx-2-0-1             4539.0        43.791607
# qb_E14-5_gdf:TTTGTCAAGCCGCCTAx-2-0-1             3979.0        29.304758
# qb_E14-5_gdf:TTTGTCAAGTCATGCTx-2-0-1             3198.0        37.552841
#
#                                       total_counts_mt  pct_counts_mt  \
# qb_E14-5_gdf:AAACCTGAGCGATGACx-2-0-0             26.0       0.593066
# qb_E14-5_gdf:AAACCTGGTGCCTGCAx-2-0-0             42.0       1.211771
# qb_E14-5_gdf:AAACCTGTCAGAAATGx-2-0-0             48.0       0.699913
# qb_E14-5_gdf:AAACGGGAGAAGGTTTx-2-0-0             18.0       0.254669
# qb_E14-5_gdf:AAACGGGGTCATTAGCx-2-0-0             37.0       1.167929
# ...                                               ...            ...
# qb_E14-5_gdf:TTTGCGCAGACTAAGTx-2-0-1            151.0       1.649913
# qb_E14-5_gdf:TTTGCGCAGTGACTCTx-2-0-1             71.0       1.541133
# qb_E14-5_gdf:TTTGGTTTCATGTCCCx-2-0-1            159.0       1.534009
# qb_E14-5_gdf:TTTGTCAAGCCGCCTAx-2-0-1             73.0       0.537634
# qb_E14-5_gdf:TTTGTCAAGTCATGCTx-2-0-1            110.0       1.291686
#
#                                      SCN_class leiden
# qb_E14-5_gdf:AAACCTGAGCGATGACx-2-0-0     SC3_B      0
# qb_E14-5_gdf:AAACCTGGTGCCTGCAx-2-0-0     SC3_B      1
# qb_E14-5_gdf:AAACCTGTCAGAAATGx-2-0-0     SC2_A      1
# qb_E14-5_gdf:AAACGGGAGAAGGTTTx-2-0-0     SC3_B      0
# qb_E14-5_gdf:AAACGGGGTCATTAGCx-2-0-0     SC2_A      1
# ...                                        ...    ...
# qb_E14-5_gdf:TTTGCGCAGACTAAGTx-2-0-1   myocyte      3
# qb_E14-5_gdf:TTTGCGCAGTGACTCTx-2-0-1    dermis      2
# qb_E14-5_gdf:TTTGGTTTCATGTCCCx-2-0-1   myocyte      3
# qb_E14-5_gdf:TTTGTCAAGCCGCCTAx-2-0-1    dermis      2
# qb_E14-5_gdf:TTTGTCAAGTCATGCTx-2-0-1   myocyte      3
#
# [1732 rows x 15 columns]

# %%
sc.pl.umap(adata, color=['leiden', 'SCN_class'], palette=sc.pl.palettes.default_20, )
# Out:
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 20, categories length: 21. Some categories will have the same color.

# %%
adata.var_names
# Out:
# Index(['Sox17', 'Mrpl15', 'Mybl1', 'Vcpip1', 'Snhg6', 'Tcf24', 'Cops5',
#        'Arfgef1', 'Cpa6', 'Slco5a1',
#        ...
#        'Gpm6b', 'Trappc2', 'Arhgap6', 'Gm21887', 'Uty', 'Ddx3y', 'Kdm5d',
#        'Eif2s3y', 'Gm29650', 'Gm47283'],
#       dtype='object', length=13621)

# %%
adata.obs["level3"].value_counts()
# Out:
# SC3_B1         653
# dermis         300
# myocyte        286
# SC2_A2          94
# blood           68
# SC3_A2          50
# SC3_B2          43
# SC2_A5          36
# SC3_B3          33
# SC2_B5          32
# SC3_B4          22
# SC2_A3          21
# SC2_B1          20
# ncc             20
# SC3_A1          13
# SC2_A4           9
# SC2_B3           7
# SC2_A6           7
# SC3_A3           3
# SC2_B4           3
# SC2_B2           3
# SC3_A4           2
# endothelial      2
# melanocyte       2
# SC2_A1           2
# erythro          1
# Name: level3, dtype: int64

# %%
adata = adata[~(adata.obs["level3"] == "erythro")]
adata.obs["level3"].value_counts()
# Out:
# SC3_B1         653
# dermis         300
# myocyte        286
# SC2_A2          94
# blood           68
# SC3_A2          50
# SC3_B2          43
# SC2_A5          36
# SC3_B3          33
# SC2_B5          32
# SC3_B4          22
# SC2_A3          21
# ncc             20
# SC2_B1          20
# SC3_A1          13
# SC2_A4           9
# SC2_B3           7
# SC2_A6           7
# SC3_A3           3
# SC2_B4           3
# SC2_B2           3
# SC3_A4           2
# endothelial      2
# melanocyte       2
# SC2_A1           2
# Name: level3, dtype: int64

# %%
# 클러스터링 결과로 rank_genes_groups를 실행
sc.tl.rank_genes_groups(adata, 'level3', use_raw=False)

# 상위 순위 유전자 목록 추출
top_genes_per_cluster = adata.uns['rank_genes_groups']['names']

# 데이터프레임 생성
gene_df = pd.DataFrame(top_genes_per_cluster)

# 상위 50개 유전자만 선택
gene_df = gene_df.iloc[:, :100]

# 데이터프레임을 엑셀 파일로 저장
gene_df.to_excel('C:/Users/yeaji/OneDrive - Johns Hopkins/PC.project/1. Cartilage devp/data/scRNA/Qin_data/Analysis/e12.5/excel/SCN_cluster/e145_SCN_cluster_rank_genes_level3.xlsx', index=False)
# Out:
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
